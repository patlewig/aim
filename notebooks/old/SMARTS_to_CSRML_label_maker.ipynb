# %% [markdown]
# <a href="https://colab.research.google.com/github/patlewig/aim/blob/master/notebooks/SMARTS_to_CSRML_label_maker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Purpose
#
# This allows us to easily add labels/titles to any SMARTS 2 CSRML conversion so we can replace the original ID:
#
# ```
# <subgraph id="r00001">
#             <molecule id="m1">
#
# ```
# To this:
#
# ```
# <subgraph id = "0">
#             <label>"‐CH3 [aliphatic carbon]"</label>
#             <title>"‐CH3 [aliphatic carbon]"</title>
#             <comment>"‐CH3 [aliphatic carbon]"</comment>
#             <molecule id="m1">
# ```
#
#
#
#
#
# ##Workflow:
#
# 1. Upload AIM Fragments Excel File
# 2. Use the SMARTS to CSRML tool in ChemoTyper to generate CSRML
# 3. Create an XML file containing newly converted AIM structures
# 4. Convert Excel to Pandas dataframe
# 5. Iterate over Pandas rows to replace XML lines
# 6. Save and Download new XML file

# %% [markdown]
# # New Section

# %%
import pandas as pd
import os
import re
os.getcwd()

# I originally tried to use an XML parser instead of Regex but it did not seem to be able to by pattern instead of <tags> and their attributes

#Chemotyper does not like "<" character in Fragment names
# Out:
# '/content'

# %%
# upload excel sheet

df = pd.read_excel('AppendixB_AIM_465_fragments_v060718_missing.xlsx' ,sheet_name='AIM_Fragments_r0_011122',header=1,usecols=list(range(0,6)))
df
# Out:
#                                       Fragment  ... Subgraph
# 0                               ‐Hg‐ [mercury]  ...   r00001
# 1                                  [Pb] (Lead)  ...   r00002
# 2                               [As] (Arsenic)  ...   r00003
# 3                             [Ge] (Germanium)  ...   r00004
# 4                                     Tin [Sn]  ...   r00005
# 5                   Tin [Sn] { oxygen attach }  ...   r00006
# 6      Tin [Sn] { oxygen and aromatic attach }  ...   r00007
# 7           Tin [Sn] { halogen or ‐OH attach }  ...   r00008
# 8                                Aluminum [Al]  ...   r00009
# 9            Gold [Au]=P { Phosphorus attach }  ...   r00010
# 10  Platinum [Pt] { halogen & nitrogen attach}  ...   r00011
# 11             Technetium [Tc](‐S)(‐S)(‐N)(‐N)  ...   r00012
# 12                          Krypton [Measured]  ...   r00013
# 13                            Argon [Measured]  ...   r00014
# 14                             Neon [Measured]  ...   r00015
# 15                            Xenon [Measured]  ...   r00016
# 16                            Radon [Measured]  ...   r00017
# 17                           Helium [Measured]  ...   r00018
# 18                          Mercury [Measured]  ...   r00019
# 19        Tin [Sn] { divalent; carbon attach }  ...   r00020
# 20      Tin [Sn] { divalent; aromatic attach }  ...   r00021
# 21                                 Sodium [Na]  ...   r00022
# 22                               Potassium [K]  ...   r00023
# 23                                Lithium [Li]  ...   r00024
# 24                                   Gold [Au]  ...   r00025
# 25                                Bismuth [Bi]  ...   r00026
# 26                                Calcium [Ca]  ...   r00027
# 27                              Magnesium [Mg]  ...   r00028
# 28                               Antimony [Sb]  ...   r00029
# 29                                   Zinc [Zn]  ...   r00030
# 30                Gold [Au] { halogen attach }  ...   r00031
# 31            Platinum [Pt] { halogen attach }  ...   r00032
# 32                               Platinum [Pt]  ...   r00033
# 33                                   Iron [Fe]  ...   r00034
# 34                                Cadmium [Cd]  ...   r00035
# 35            Cadmium [Cd] { halogen attach\n}  ...   r00036
# 36           Miscellaneous Metal [Ni,Cu,Zr,Be]  ...   r00037
# 37      Miscellaneous Elements (Value Unknown)  ...   r00038
# 38       Tin [Sn] { multi‐halogen or ‐\nONO2 }  ...   r00039
# 39                Tin [Sn] { nitrogen attach }  ...   r00040
# 40                      [Zn]‐S { zinc‐sulfur }  ...   r00041
# 41               [Sn]‐O‐[Sn] { bis‐tin ether }  ...   r00042
# 42                                        [He]  ...   r00043
# 43                                        [Ne]  ...   r00044
# 44                                        [Ar]  ...   r00045
# 45                                        [Kr]  ...   r00046
# 46                                        [Xe]  ...   r00047
# 47                                        [Rn]  ...   r00048
#
# [48 rows x 6 columns]

# %%
# Just to show what we want to be inside of our file vs what the converter does
for index, row in df.iterrows():
  if index<=1:
    original_subgraph = '<subgraph id ="'+str(row['Subgraph']) + '">'
    subgraph = '<subgraph id = "'+str(row['Id']) + '">'
    label = '     <label>"'+ row['Fragment'] +'"</label>'
    title = '     <title>"'+ row['Fragment'] +'"</title>'
    comment= '     <comment>"'+ row['Fragment'] +'"</comment>'
    #print(original_subgraph)
    print(subgraph + '\n' + label + '\n' + title + '\n' + comment)
# Out:
# <subgraph id = "310C">
#      <label>"‐Hg‐ [mercury]"</label>
#      <title>"‐Hg‐ [mercury]"</title>
#      <comment>"‐Hg‐ [mercury]"</comment>
# <subgraph id = "311C">
#      <label>"[Pb] (Lead)"</label>
#      <title>"[Pb] (Lead)"</title>
#      <comment>"[Pb] (Lead)"</comment>

# %%
# Open and read our XML file_1239
with open ("AIM_V1.10_miss.xml", "r") as myfile:
    data = myfile.read()
print(data)
# Out:
# <?xml version='1.0' encoding='utf-8'?>
# <csrml xmlns="http://www.molecular-networks.com/schema/csrml" id="AIM_v1_0" csrmlVersion="2">
#
# 	<title>
# 		AIM Chemotypes Version 1.0
# 	</title>
# 	<description>
# 		$Id: AIM_V1.0.xml 711 2022-01-19 madams $
# 		@manualVersion: v.1.0
# 		@lastChangedBy: $Author: madams $
# 		@revision:      $Revision: 0 $
# 	</description>
#
# 	<classes id="AIM_v1_0">
# 		<title>AIM Chemotypes Version 1.0</title>
# 		<comment>symphony_display</comment>
# 		<class id="class_0001">
# 			<label>atom</label>
# 			<class id="class_0002">
# 				<label>element</label>
# 			</class>
#                 </class>
# 		<class id="class_0003">
# 		        <label>bond</label>
# 			<class id="class_0004">
# 				<label>C#N</label>
#
# 			</class>
# 			<class id="class_0005">
# 				<label>C(~Z)~C~Q</label>
#
# 			</class>
# 			<class id="class_0006">
# 				<label>C(=O)N</label>
#
# 			</class>
# 			<class id="class_0007">
# 				<label>C(=O)O</label>
# 			</class>
# 			<class id="class_0008">
# 				<label>C=N</label>
# 			</class>
# 			<class id="class_0009">
# 				<label>C=O</label>
# 			</class>
# 			<class id="class_0010">
# 				<label>C=S</label>
# 			</class>
# 			<class id="class_0011">
# 				<label>CC(=O)C</label>
# 			</class>
# 			<class id="class_0012">
# 				<label>CN</label>
# 			</class>
# 			<class id="class_0013">
# 				<label>CNO</label>
# 			</class>
# 			<class id="class_0014">
# 				<label>COC</label>
# 			</class>
# 			<class id="class_0015">
# 				<label>COH</label>
# 			</class>
# 			<class id="class_0016">
# 				<label>CS</label>
# 			</class>
# 			<class id="class_0017">
# 				<label>CX</label>
# 			</class>
# 			<class id="class_0018">
# 				<label>N(=O)</label>
# 			</class>
# 			<class id="class_0019">
# 				<label>N[!C]</label>
# 			</class>
# 			<class id="class_0020">
# 				<label>N=[N+]=[N-]</label>
# 			</class>
# 			<class id="class_0021">
# 				<label>N=C=O</label>
# 			</class>
# 			<class id="class_0022">
# 				<label>N=N</label>
# 			</class>
# 			<class id="class_0023">
# 				<label>N=O</label>
# 			</class>
# 			<class id="class_0024">
# 				<label>NC=O</label>
# 			</class>
# 			<class id="class_0025">
# 				<label>NN</label>
# 			</class>
# 			<class id="class_0026">
# 				<label>NN=N</label>
# 			</class>
# 			<class id="class_0027">
# 				<label>NO</label>
# 			</class>
# 			<class id="class_0028">
# 				<label>OZ</label>
# 			</class>
# 			<class id="class_0029">
# 				<label>P(=O)N</label>
# 			</class>
# 			<class id="class_0030">
# 				<label>P=C</label>
# 			</class>
# 			<class id="class_0031">
# 				<label>P=O</label>
# 			</class>
# 			<class id="class_0032">
# 				<label>PC</label>
# 			</class>
# 			<class id="class_0033">
# 				<label>PO</label>
# 			</class>
# 			<class id="class_0034">
# 				<label>P~N</label>
# 			</class>
# 			<class id="class_0035">
# 				<label>P~S</label>
# 			</class>
# 			<class id="class_0036">
# 				<label>QQ(Q~O S)</label>
# 			</class>
# 			<class id="class_0037">
# 				<label>quatN</label>
# 			</class>
# 			<class id="class_0038">
# 				<label>quatP</label>
# 			</class>
# 			<class id="class_0039">
# 				<label>quatS</label>
# 			</class>
# 			<class id="class_0040">
# 				<label>S(=O)N</label>
# 			</class>
# 			<class id="class_0041">
# 				<label>S(=O)O</label>
# 			</class>
# 			<class id="class_0042">
# 				<label>S(=O)X</label>
# 			</class>
# 			<class id="class_0043">
# 				<label>S=O</label>
# 			</class>
# 			<class id="class_0044">
# 				<label>S~N</label>
# 			</class>
# 			<class id="class_0045">
# 				<label>Se~Q</label>
# 			</class>
# 			<class id="class_0046">
# 				<label>X[any]</label>
# 			</class>
# 			<class id="class_0047">
# 				<label>X[any !C]</label>
# 			</class>
# 			<class id="class_0048">
# 				<label>X~Z</label>
# 			</class>
# 			<class id="class_0049">
# 				<label>metal</label>
# 			</class>
# 		</class>
# 		<class id="class_0050">
# 			<label>chain</label>
# 			<class id="class_0051">
# 				<label>alkaneBranch</label>
# 			</class>
# 			<class id="class_0052">
# 				<label>alkaneCyclic</label>
# 			</class>
# 			<class id="class_0053">
# 				<label>alkaneLinear</label>
# 			</class>
# 			<class id="class_0054">
# 				<label>alkeneBranch</label>
# 			</class>
# 			<class id="class_0055">
# 				<label>alkeneCyclic</label>
# 			</class>
# 			<class id="class_0056">
# 				<label>alkeneLinear</label>
# 			</class>
# 			<class id="class_0057">
# 				<label>alkyne</label>
# 			</class>
# 			<class id="class_0058">
# 				<label>aromaticAlkane</label>
# 			</class>
# 			<class id="class_0059">
# 				<label>aromaticAlkene</label>
# 			</class>
# 			<class id="class_0061">
# 				<label>oxy-alkaneBranch</label>
# 			</class>
# 			<class id="class_0060">
# 				<label>oxy-alkaneLinear</label>
# 			</class>
# 		</class>
# 		<class id="class_0062">
# 			<label>group</label>
# 			<class id="class_0063">
# 				<label>aminoAcid</label>
# 			</class>
# 			<class id="class_0064">
# 				<label>carbohydrate</label>
# 			</class>
# 			<class id="class_0065">
# 				<label>ligand</label>
# 			</class>
# 			<class id="class_0066">
# 				<label>nucleobase</label>
# 			</class>
# 		</class>
# 		<class id="class_0067">
# 			<label>ring</label>
# 			<class id="class_0068">
# 				<label>aromatic</label>
# 			</class>
# 			<class id="class_0069">
# 				<label>fused</label>
# 			</class>
# 			<class id="class_0070">
# 				<label>hetero</label>
# 			</class>
# 			<class id="class_0071">
# 				<label>polycycle</label>
# 			</class>
# 		</class>
#     </classes>
#         <subgraph id="r00001">
#             <molecule id="m1">
#                 <!-- converter info: [Hg] at line 2-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Hg">
#                         <!-- converter info: symbol==Hg-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00002">
#             <molecule id="m1">
#                 <!-- converter info: [Pb] at line 3-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Pb">
#                         <!-- converter info: symbol==Pb-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00003">
#             <molecule id="m1">
#                 <!-- converter info: [As] at line 4-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="As">
#                         <!-- converter info: symbol==As-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00004">
#             <molecule id="m1">
#                 <!-- converter info: [Ge] at line 5-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ge">
#                         <!-- converter info: symbol==Ge-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00005">
#             <molecule id="m1">
#                 <!-- converter info: [Sn] at line 6-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Sn">
#                         <!-- converter info: symbol==Sn-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00006">
#             <molecule id="m1">
#                 <!-- converter info: [SnX4](C)(C)(C)[O][!#1] at line 7-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, connectivity==4)-->
#                         <matchIf feature="connectivity">
#                             <value>
#                                 4
#                             </value>
#                         </matchIf>
#                     </atom>
#                     <atom id="a2" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a3" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a4" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a5" element="O">
#                         <!-- converter info: AND(symbol==O, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a6" element="QRY">
#                         <!-- converter info: NOT (number==1)-->
#                         <matchIf feature="atomList" negate="true">
#                             <value>
#                                 H
#                             </value>
#                         </matchIf>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a3"/>
#                     </bond>
#                     <bond id="b3" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a4"/>
#                     </bond>
#                     <bond id="b4" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a5"/>
#                     </bond>
#                     <bond id="b5" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a5"/>
#                         <atom id="a6"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00007">
#             <molecule id="m1">
#                 <!-- converter info: [cR][Snv2]O[!#1] at line 8-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==true, ring==true)-->
#                         <matchIf feature="aromaticAtom"/>
#                         <matchIf feature="ringAtom"/>
#                     </atom>
#                     <atom id="a2" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, total bond order==2)-->
#                         <matchIf feature="valency">
#                             <value>
#                                 2
#                             </value>
#                         </matchIf>
#                     </atom>
#                     <atom id="a3" element="O">
#                         <!-- converter info: AND(symbol==O, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a4" element="QRY">
#                         <!-- converter info: NOT (number==1)-->
#                         <matchIf feature="atomList" negate="true">
#                             <value>
#                                 H
#                             </value>
#                         </matchIf>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                     <bond id="b3" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a3"/>
#                         <atom id="a4"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00008">
#             <molecule id="m1">
#                 <!-- converter info: [#6][Snv2,Snv4][Mt] at line 9-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="C">
#                         <!-- converter info: number==6-->
#                     </atom>
#                     <atom id="a2" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, aromatic==false, OR(total bond order==2, total bond order==4))-->
#                         <matchIf feature="aliphaticAtom"/>
#                         <matchIf feature="combineAtomFeatures" combineBy="or">
#                             <matchIf feature="valency">
#                                 <value>
#                                     2
#                                 </value>
#                             </matchIf>
#                             <matchIf feature="valency">
#                                 <value>
#                                     4
#                                 </value>
#                             </matchIf>
#                         </matchIf>
#                     </atom>
#                     <atom id="a3" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="query">
#                         <!-- converter info: unspecifiedBond==-:-->
#                         <matchIf feature="combineBondFeatures" combineBy="or">
#                             <matchIf feature="bondList">
#                                 <value>
#                                     single
#                                 </value>
#                             </matchIf>
#                             <matchIf feature="aromaticBond"/>
#                         </matchIf>
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00009">
#             <molecule id="m1">
#                 <!-- converter info: [Al] at line 10-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Al">
#                         <!-- converter info: symbol==Al-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00010">
#             <molecule id="m1">
#                 <!-- converter info: [Au]=P at line 11-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" x="0" y="0" element="Au">
#                         <!-- converter info: symbol==Au-->
#                     </atom>
#                     <atom id="a2" x="1" y="0" element="P">
#                         <!-- converter info: AND(symbol==P, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="double">
#                         <!-- converter info: symbol===-->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00011">
#             <molecule id="m1">
#                 <!-- converter info: [Mt][Pt]N at line 12-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                     <atom id="a2" element="Pt">
#                         <!-- converter info: symbol==Pt-->
#                     </atom>
#                     <atom id="a3" element="N">
#                         <!-- converter info: AND(symbol==N, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00012">
#             <molecule id="m1">
#                 <!-- converter info: [Tc] at line 13-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Tc">
#                         <!-- converter info: symbol==Tc-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00013">
#             <molecule id="m1">
#                 <!-- converter info: [Kr] at line 14-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Kr">
#                         <!-- converter info: symbol==Kr-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00014">
#             <molecule id="m1">
#                 <!-- converter info: [Ar] at line 15-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ar">
#                         <!-- converter info: symbol==Ar-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00015">
#             <molecule id="m1">
#                 <!-- converter info: [Ne] at line 16-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ne">
#                         <!-- converter info: symbol==Ne-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00016">
#             <molecule id="m1">
#                 <!-- converter info: [Xe] at line 17-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Xe">
#                         <!-- converter info: symbol==Xe-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00017">
#             <molecule id="m1">
#                 <!-- converter info: [Rn] at line 18-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Rn">
#                         <!-- converter info: symbol==Rn-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00018">
#             <molecule id="m1">
#                 <!-- converter info: [He] at line 19-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="He">
#                         <!-- converter info: symbol==He-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00019">
#             <molecule id="m1">
#                 <!-- converter info: [Hg] at line 20-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Hg">
#                         <!-- converter info: symbol==Hg-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00020">
#             <molecule id="m1">
#                 <!-- converter info: C[SnX2]C at line 21-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a2" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, connectivity==2)-->
#                         <matchIf feature="connectivity">
#                             <value>
#                                 2
#                             </value>
#                         </matchIf>
#                     </atom>
#                     <atom id="a3" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00021">
#             <molecule id="m1">
#                 <!-- converter info: [cR][SnX2][cR] at line 22-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==true, ring==true)-->
#                         <matchIf feature="aromaticAtom"/>
#                         <matchIf feature="ringAtom"/>
#                     </atom>
#                     <atom id="a2" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, connectivity==2)-->
#                         <matchIf feature="connectivity">
#                             <value>
#                                 2
#                             </value>
#                         </matchIf>
#                     </atom>
#                     <atom id="a3" element="C">
#                         <!-- converter info: AND(symbol==C, aromatic==true, ring==true)-->
#                         <matchIf feature="aromaticAtom"/>
#                         <matchIf feature="ringAtom"/>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00022">
#             <molecule id="m1">
#                 <!-- converter info: [Na] at line 23-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Na">
#                         <!-- converter info: symbol==Na-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00023">
#             <molecule id="m1">
#                 <!-- converter info: [K] at line 24-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="K">
#                         <!-- converter info: symbol==K-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00024">
#             <molecule id="m1">
#                 <!-- converter info: [Li] at line 25-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Li">
#                         <!-- converter info: symbol==Li-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00025">
#             <molecule id="m1">
#                 <!-- converter info: [Au] at line 26-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Au">
#                         <!-- converter info: symbol==Au-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00026">
#             <molecule id="m1">
#                 <!-- converter info: [Bi] at line 27-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Bi">
#                         <!-- converter info: symbol==Bi-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00027">
#             <molecule id="m1">
#                 <!-- converter info: [Ca] at line 28-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ca">
#                         <!-- converter info: symbol==Ca-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00028">
#             <molecule id="m1">
#                 <!-- converter info: [Mg] at line 29-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Mg">
#                         <!-- converter info: symbol==Mg-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00029">
#             <molecule id="m1">
#                 <!-- converter info: [Sb] at line 30-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Sb">
#                         <!-- converter info: symbol==Sb-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00030">
#             <molecule id="m1">
#                 <!-- converter info: [Zn] at line 31-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Zn">
#                         <!-- converter info: symbol==Zn-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00031">
#             <molecule id="m1">
#                 <!-- converter info: [Mt][Au][#1,#6] at line 32-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                     <atom id="a2" element="Au">
#                         <!-- converter info: symbol==Au-->
#                     </atom>
#                     <atom id="a3" element="QRY">
#                         <!-- converter info: symbol==H,C-->
#                         <matchIf feature="atomList">
#                             <value>
#                                 H
#                             </value>
#                             <value>
#                                 C
#                             </value>
#                         </matchIf>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00032">
#             <molecule id="m1">
#                 <!-- converter info: P[Mt] at line 33-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" x="0" y="0" element="P">
#                         <!-- converter info: AND(symbol==P, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a2" x="1" y="0" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00033">
#             <molecule id="m1">
#                 <!-- converter info: [Pt] at line 34-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Pt">
#                         <!-- converter info: symbol==Pt-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00034">
#             <molecule id="m1">
#                 <!-- converter info: [Fe] at line 35-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
# ...
#                 <!-- converter info: [Ni,Cu,Zr,Be] at line 38-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="QRY">
#                         <!-- converter info: symbol==Ni,Cu,Zr,Be-->
#                         <matchIf feature="atomList">
#                             <value>
#                                 Ni
#                             </value>
#                             <value>
#                                 Cu
#                             </value>
#                             <value>
#                                 Zr
#                             </value>
#                             <value>
#                                 Be
#                             </value>
#                         </matchIf>
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00038">
#             <molecule id="m1">
#                 <!-- converter info: [Mn] at line 39-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Mn">
#                         <!-- converter info: symbol==Mn-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00039">
#             <molecule id="m1">
#                 <!-- converter info: [Snv2,Snv4]([Mt])([Mt]) at line 40-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, aromatic==false, OR(total bond order==2, total bond order==4))-->
#                         <matchIf feature="aliphaticAtom"/>
#                         <matchIf feature="combineAtomFeatures" combineBy="or">
#                             <matchIf feature="valency">
#                                 <value>
#                                     2
#                                 </value>
#                             </matchIf>
#                             <matchIf feature="valency">
#                                 <value>
#                                     4
#                                 </value>
#                             </matchIf>
#                         </matchIf>
#                     </atom>
#                     <atom id="a2" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                     <atom id="a3" element="Mt">
#                         <!-- converter info: symbol==Mt-->
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00040">
#             <molecule id="m1">
#                 <!-- converter info: [Snv2,Snv4][NX3] at line 41-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" x="0" y="0" element="Sn">
#                         <!-- converter info: AND(symbol==Sn, aromatic==false, OR(total bond order==2, total bond order==4))-->
#                         <matchIf feature="aliphaticAtom"/>
#                         <matchIf feature="combineAtomFeatures" combineBy="or">
#                             <matchIf feature="valency">
#                                 <value>
#                                     2
#                                 </value>
#                             </matchIf>
#                             <matchIf feature="valency">
#                                 <value>
#                                     4
#                                 </value>
#                             </matchIf>
#                         </matchIf>
#                     </atom>
#                     <atom id="a2" x="1" y="0" element="N">
#                         <!-- converter info: AND(symbol==N, aromatic==false, connectivity==3)-->
#                         <matchIf feature="aliphaticAtom"/>
#                         <matchIf feature="connectivity">
#                             <value>
#                                 3
#                             </value>
#                         </matchIf>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00041">
#             <molecule id="m1">
#                 <!-- converter info: [Zn][S] at line 42-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" x="0" y="0" element="Zn">
#                         <!-- converter info: symbol==Zn-->
#                     </atom>
#                     <atom id="a2" x="1" y="0" element="S">
#                         <!-- converter info: AND(symbol==S, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00042">
#             <molecule id="m1">
#                 <!-- converter info: [Sn]O[Sn] at line 43-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Sn">
#                         <!-- converter info: symbol==Sn-->
#                     </atom>
#                     <atom id="a2" element="O">
#                         <!-- converter info: AND(symbol==O, aromatic==false)-->
#                         <matchIf feature="aliphaticAtom"/>
#                     </atom>
#                     <atom id="a3" element="Sn">
#                         <!-- converter info: symbol==Sn-->
#                     </atom>
#                 </atoms>
#                 <bonds>
#                     <bond id="b1" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a1"/>
#                         <atom id="a2"/>
#                     </bond>
#                     <bond id="b2" order="single">
#                         <!-- converter info: symbol==- -->
#                         <atom id="a2"/>
#                         <atom id="a3"/>
#                     </bond>
#                 </bonds>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00043">
#             <molecule id="m1">
#                 <!-- converter info: [He] at line 44-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="He">
#                         <!-- converter info: symbol==He-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00044">
#             <molecule id="m1">
#                 <!-- converter info: [Ne] at line 45-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ne">
#                         <!-- converter info: symbol==Ne-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00045">
#             <molecule id="m1">
#                 <!-- converter info: [Ar] at line 46-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Ar">
#                         <!-- converter info: symbol==Ar-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00046">
#             <molecule id="m1">
#                 <!-- converter info: [Kr] at line 47-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Kr">
#                         <!-- converter info: symbol==Kr-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00047">
#             <molecule id="m1">
#                 <!-- converter info: [Xe] at line 48-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Xe">
#                         <!-- converter info: symbol==Xe-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#         <subgraph id="r00048">
#             <molecule id="m1">
#                 <!-- converter info: [Rn] at line 49-->
#                 <matchIf feature="substructureMatch"/>
#                 <atoms>
#                     <atom id="a1" element="Rn">
#                         <!-- converter info: symbol==Rn-->
#                     </atom>
#                 </atoms>
#                 <bonds/>
#             </molecule>
#             <mustMatch>
#                 <molecule id="mustMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustMatch>
#             <mustNotMatch>
#                 <molecule id="mustNotMatch_1">
#                     <atoms>
#                         <atom id="O" element="O"/>
#                     </atoms>
#                     <bonds/>
#                 </molecule>
#             </mustNotMatch>
#         </subgraph>
#     </csrml>

# %%
# Replace the text patterns with our desired pattern inside of our XML file
for index, row in df.iterrows():
    subgraph = '<subgraph id = "'+str(row['Id']) + '">'
    label = '            <label>"'+ str(row['Fragment']) +'"</label>'
    title = '            <title>"'+ str(row['Fragment']) +'"</title>'
    comment= '            <comment>"'+ str(row['Fragment']) +'"</comment>'
    data = re.sub(r'<subgraph id="\b{}\b">'.format(row['Subgraph']), subgraph + '\n' + label + '\n' + title + '\n' + comment, data)

#print(re.findall(r'"(.*[<|&].*)"',data))
for match in re.findall(r'"(.*[<|&].*)"',data):    
      match_sub = re.sub(r"[<|&]","",match)   #remove < and &
      #match_sub = re.sub(r"&","and",match)           
      data = re.sub(re.escape(match), match_sub, data)   

data = re.sub("Mt", "X", data)   #Replace Mt with X (Mt is recognized by converter but unused, X is not recgonized but represents Halogens)

#Fixes elementList and bondList <value> problem

strings = re.findall(r'<value>\n  *[a-zA-Z]{1,6}\n  *',data)

#print(strings)
for string in strings:
 string = "".join(string.split())
 #print(string[7:])
 data = re.sub(r'<value>\n  *\b{}\b\n  *'.format(string[7:]),string, data)

# %%
#Write our changes to new XML file
import xml.etree.ElementTree as ET
myfile = open("AIM_V1.10_missing.xml", "w")
myfile.write(data)
# Out:
# 73735
