# %% [markdown]
# #### Looking at performance of Individual group:
#
# What fragments are found signicantly higher representation compared to the entire set?
#
# How do the AIM vs Toxprints compare (are there more AIM / tox fragments found to be present in the group)
#
# How is the performance of predictions (both good, one good, neither good)
#
# <!--
# #### Compare groups?:
#
# Are there groups which have a similar distribution of fragments?  (More similar compounds. eg. the benz subclasses)
#
# Of the groups that are similar, how do the predictions compare
#  -->

# %% [markdown]
# #### Author: Matthew Adams
# #### Principal Investigator: Grace Patlewicz
# #### Last Modified Sept 22 2022

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import os

# %%
TOP = os.getcwd().replace('notebooks', '')
raw_dir = TOP + 'data/raw/'
processed_dir = TOP +'data/processed/'
interim_dir = TOP + 'data/interim/'
external_dir = TOP + 'data/external/'
figures_dir = TOP + 'reports/figures/'

# %%
df = pd.read_csv(processed_dir+'htpp_parsed_classyfire_data.csv')

# %% [markdown]
# ## Load in Classyfire data
#  - This gives us an assigned class labels for each DTXSID so we can group our chemicals based on structural similarity

# %%
df.head()
# Out:
#           dtxsid            kingdom                superclass  \
# 0  DTXSID5020281  organic compounds                benzenoids
# 1  DTXSID8020961  organic compounds                benzenoids
# 2  DTXSID0021834  organic compounds                benzenoids
# 3  DTXSID2044347  organic compounds  organic oxygen compounds
# 4  DTXSID4025745  organic compounds                benzenoids
#
#                                  class            subclass  \
# 0  benzene and substituted derivatives       nitrobenzenes
# 1  benzene and substituted derivatives       nitrobenzenes
# 2                              phenols        nitrophenols
# 3               organooxygen compounds  carbonyl compounds
# 4  benzene and substituted derivatives       nitrobenzenes
#
#                                         substituents
# 0  nitrobenzene|nitroaromatic compound|chlorobenz...
# 1  nitrobenzene|nitroaromatic compound|aniline or...
# 2  nitrophenol|nitrobenzene|nitroaromatic compoun...
# 3  alkyl-phenylketone|acetophenone|phenoxy compou...
# 4  nitrobenzene|nitroaromatic compound|benzyl hal...

# %% [markdown]
# Look at clusters (mean error) --> fragment distribution in individual cluster --> Errors of individual structures in cluster

# %%
df = df[['dtxsid','class','subclass']]

# %%
df.shape
# Out:
# (6932, 3)

# %%
#df[df['class'].isnull()]

# %% [markdown]
# ## Create a table for our groups
#
# We are interested in creating groups which contain enough chemicals but that are more distinct compared to the general chemical population

# %%
# Most CLASSES are fine, but some are too generalized so use SUBCLASSES when necessary

chem_classes = list(set([row for row in df['class']]))
chem_classes = [x for x in chem_classes if str(x) != 'nan']

grps = []
N_structs = []
for i in chem_classes:
    df2 = df[df['class'] == i]
    if len(df2) > 200: # If our class is too broad, (benz); want to use subclasses (more specified) instead
        subclasses = list(set([row for row in df2['subclass']]))  
        subclasses = [x for x in subclasses if str(x) != 'nan']
        for j in subclasses:
            df3 = df[df['subclass']==j]
            grps.append(j)
            N_structs.append(len(df3))
    else:
        grps.append(i)
        N_structs.append(len(df2))

df_lens = pd.DataFrame.from_dict(zip(grps,N_structs))
df_lens = df_lens.rename(columns={0:'Group',1:'N_struct'})


df_lens[df_lens['N_struct']>20]
# Out:
#                                               Group  N_struct
# 2                                       benzopyrans        23
# 4    organic dithiophosphoric acids and derivatives        44
# 5                                     benzodioxoles        24
# 9                                         coumarans        24
# 21                 steroids and steroid derivatives        41
# ..                                              ...       ...
# 321        allyl-type 1,3-dipolar organic compounds        23
# 327                                 benzodiazepines        36
# 331    organic thiophosphoric acids and derivatives        99
# 334                                      thioethers        51
# 335                                     piperidines        39
#
# [88 rows x 2 columns]

# %%
df_lens[df_lens['N_struct']>20]['N_struct'].sum()
# Out:
# 5472

# %%
df_lens[df_lens['Group'] == 'phenoxyacetic acid derivatives']
# Out:
#                               Group  N_struct
# 187  phenoxyacetic acid derivatives        43

# %%
[e for e in df_lens.Group.unique().tolist() if "hetero" in e]
# Out:
# ['heteroaromatic compounds']

# %%
df_lens[df_lens['Group'] == 'heteroaromatic compounds']
# Out:
#                        Group  N_struct
# 32  heteroaromatic compounds        10

# %% [markdown]
# We end up with 88 different groups, currently the only information included is the number of chemicals per group.
#
# Next, we want to pull additional information for each group

# %% [markdown]
# ## Join dataframes
#
# We want to include all necessary information in a single table (aim,toxprints,classes)

# %%
txp_predictions = pd.read_csv(processed_dir+'txp_predictions_genra.csv')

# %%
txp_predictions
# Out:
#       Unnamed: 0    Y_true    Y_pred      Diff  residual       mse  \
# 0              0 -0.465339 -0.346871  0.118469  0.118469  0.014035
# 1              1 -0.734786 -0.838397  0.103611 -0.103611  0.010735
# 2              2 -0.087091 -0.020099  0.066992  0.066992  0.004488
# 3              3 -1.058925 -1.077005  0.018080 -0.018080  0.000327
# 4              4 -1.022972 -0.927933  0.095039  0.095039  0.009032
# ...          ...       ...       ...       ...       ...       ...
# 6967        6967 -0.184418 -1.149901  0.965483 -0.965483  0.932157
# 6968        6968  1.942702  0.940935  1.001768 -1.001768  1.003539
# 6969        6969 -0.283519 -0.625075  0.341556 -0.341556  0.116660
# 6970        6970 -0.579302 -0.190255  0.389047  0.389047  0.151358
# 6971        6971 -0.719993 -0.701917  0.018076  0.018076  0.000327
#
#               dtxsid                                           txp_list
# 0      DTXSID5020281  ['bond:CX_halide_aromatic-X_generic', 'bond:N(...
# 1      DTXSID8020961  ['bond:CN_amine_aromatic_generic', 'bond:CN_am...
# 2      DTXSID0021834  ['bond:COH_alcohol_aromatic', 'bond:COH_alcoho...
# 3      DTXSID2044347  ['bond:C=O_carbonyl_ab-unsaturated_generic', '...
# 4      DTXSID4025745  ['bond:CX_halide_alkyl-X_aromatic_alkane', 'bo...
# ...              ...                                                ...
# 6967   DTXSID3044752  ['bond:C(=O)O_carboxylicEster_acyclic', 'bond:...
# 6968  DTXSID80244288  ['bond:CS_sulfide', 'bond:PC_phosphorus_organo...
# 6969   DTXSID0022143  ['bond:C(=O)O_carboxylicEster_acyclic', 'bond:...
# 6970   DTXSID6020303  ['bond:CX_halide_alkyl-Cl_ethyl', 'bond:CX_hal...
# 6971   DTXSID2025395  ['atom:element_metal_metalloid', 'bond:N[!C]_a...
#
# [6972 rows x 8 columns]

# %%
Toxprint_FP = pd.read_csv(raw_dir+'CHM0_apr1_tox.txt',sep=';')
Toxprint_FP = Toxprint_FP[Toxprint_FP['M_CORINA_SYMPHONY_ERRORS_[STRING]'] == 'No errors']
Toxprint_FP = Toxprint_FP.iloc[:,0:-2]
Toxprint_FP = Toxprint_FP.set_index('M_NAME').rename_axis(index=None)
Toxprint_FP.head()
# Out:
#                atom:element_main_group  atom:element_metal_group_I_II  \
# DTXSID5020281                        0                              0
# DTXSID8020961                        0                              0
# DTXSID0021834                        0                              0
# DTXSID2044347                        0                              0
# DTXSID4025745                        0                              0
#
#                atom:element_metal_group_III  atom:element_metal_metalloid  \
# DTXSID5020281                             0                             0
# DTXSID8020961                             0                             0
# DTXSID0021834                             0                             0
# DTXSID2044347                             0                             0
# DTXSID4025745                             0                             0
#
#                atom:element_metal_poor_metal  \
# DTXSID5020281                              0
# DTXSID8020961                              0
# DTXSID0021834                              0
# DTXSID2044347                              0
# DTXSID4025745                              0
#
#                atom:element_metal_transistion_metal  atom:element_noble_gas  \
# DTXSID5020281                                     0                       0
# DTXSID8020961                                     0                       0
# DTXSID0021834                                     0                       0
# DTXSID2044347                                     0                       0
# DTXSID4025745                                     0                       0
#
#                bond:C#N_cyano_acylcyanide  bond:C#N_cyano_cyanamide  \
# DTXSID5020281                           0                         0
# DTXSID8020961                           0                         0
# DTXSID0021834                           0                         0
# DTXSID2044347                           0                         0
# DTXSID4025745                           0                         0
#
#                bond:C#N_cyano_cyanohydrin  ...  \
# DTXSID5020281                           0  ...
# DTXSID8020961                           0  ...
# DTXSID0021834                           0  ...
# DTXSID2044347                           0  ...
# DTXSID4025745                           0  ...
#
#                ring:polycycle_bicyclo_propene  \
# DTXSID5020281                               0
# DTXSID8020961                               0
# DTXSID0021834                               0
# DTXSID2044347                               0
# DTXSID4025745                               0
#
#                ring:polycycle_spiro_[2.2]pentane  \
# DTXSID5020281                                  0
# DTXSID8020961                                  0
# DTXSID0021834                                  0
# DTXSID2044347                                  0
# DTXSID4025745                                  0
#
#                ring:polycycle_spiro_[2.5]octane  \
# DTXSID5020281                                 0
# DTXSID8020961                                 0
# DTXSID0021834                                 0
# DTXSID2044347                                 0
# DTXSID4025745                                 0
#
#                ring:polycycle_spiro_[4.5]decane  \
# DTXSID5020281                                 0
# DTXSID8020961                                 0
# DTXSID0021834                                 0
# DTXSID2044347                                 0
# DTXSID4025745                                 0
#
#                ring:polycycle_spiro_1_4-dioxaspiro[4.5]decane  \
# DTXSID5020281                                               0
# DTXSID8020961                                               0
# DTXSID0021834                                               0
# DTXSID2044347                                               0
# DTXSID4025745                                               0
#
#                ring:polycycle_tricyclo_[3.5.5]_cyclopropa[cd]pentalene  \
# DTXSID5020281                                                  0
# DTXSID8020961                                                  0
# DTXSID0021834                                                  0
# DTXSID2044347                                                  0
# DTXSID4025745                                                  0
#
#                ring:polycycle_tricyclo_[3.7.7]bullvalene  \
# DTXSID5020281                                          0
# DTXSID8020961                                          0
# DTXSID0021834                                          0
# DTXSID2044347                                          0
# DTXSID4025745                                          0
#
#                ring:polycycle_tricyclo_[3.7.7]semibullvalene  \
# DTXSID5020281                                              0
# DTXSID8020961                                              0
# DTXSID0021834                                              0
# DTXSID2044347                                              0
# DTXSID4025745                                              0
#
#                ring:polycycle_tricyclo_adamantane  \
# DTXSID5020281                                   0
# DTXSID8020961                                   0
# DTXSID0021834                                   0
# DTXSID2044347                                   0
# DTXSID4025745                                   0
#
#                ring:polycycle_tricyclo_benzvalene
# DTXSID5020281                                   0
# DTXSID8020961                                   0
# DTXSID0021834                                   0
# DTXSID2044347                                   0
# DTXSID4025745                                   0
#
# [5 rows x 729 columns]

# %%
cols = {k:v for k,v in enumerate(Toxprint_FP.columns)}

# %%
FPs = {}
for i,group in Toxprint_FP.iterrows():
    a = np.where(group.values ==1)
    b = [cols[e] for e in a[0]]
    FPs[i] =b

# %%
FP_df = pd.DataFrame(list(FPs.items()), columns = ['dtxsid', 'tox_list'])

# %%
txp_predictions = pd.merge(txp_predictions, FP_df, on = 'dtxsid', how = 'left')

# %%
txp_predictions = txp_predictions[['Y_true', 'Y_pred', 'Diff', 'dtxsid', 'tox_list']]

# %%
txp_predictions.head()
# Out:
#      Y_true    Y_pred      Diff         dtxsid  \
# 0 -0.465339 -0.346871  0.118469  DTXSID5020281
# 1 -0.734786 -0.838397  0.103611  DTXSID8020961
# 2 -0.087091 -0.020099  0.066992  DTXSID0021834
# 3 -1.058925 -1.077005  0.018080  DTXSID2044347
# 4 -1.022972 -0.927933  0.095039  DTXSID4025745
#
#                                             tox_list
# 0  [bond:CX_halide_aromatic-X_generic, bond:N(=O)...
# 1  [bond:CN_amine_aromatic_generic, bond:CN_amine...
# 2  [bond:COH_alcohol_aromatic, bond:COH_alcohol_a...
# 3  [bond:C=O_carbonyl_ab-unsaturated_generic, bon...
# 4  [bond:CX_halide_alkyl-X_aromatic_alkane, bond:...

# %%
aim_predictions = pd.read_csv(processed_dir+'aim_predictions_genra.csv')

# %%
aim_predictions
# Out:
#       Unnamed: 0    Y_true    Y_pred      Diff  residual       mse  \
# 0              0 -0.465339 -0.329968  0.135371  0.135371  0.018325
# 1              1 -0.734786 -0.842910  0.108124 -0.108124  0.011691
# 2              2 -0.087091 -0.569759  0.482668 -0.482668  0.232969
# 3              3 -1.058925 -1.143505  0.084580 -0.084580  0.007154
# 4              4 -1.022972 -0.786114  0.236858  0.236858  0.056102
# ...          ...       ...       ...       ...       ...       ...
# 6963        6963 -0.184418 -0.580946  0.396529 -0.396529  0.157235
# 6964        6964  1.942702  0.015562  1.927141 -1.927141  3.713872
# 6965        6965 -0.283519 -1.318011  1.034492 -1.034492  1.070173
# 6966        6966 -0.579302 -0.640617  0.061316 -0.061316  0.003760
# 6967        6967 -0.719993 -0.637765  0.082229  0.082229  0.006762
#
#               dtxsid                                           aim_list
# 0      DTXSID5020281  ['Aromatic Carbon', ' CL [chlorine, aromatic a...
# 1      DTXSID8020961  ['Aromatic Carbon', ' N [aliphatic N, one arom...
# 2      DTXSID0021834  ['Aromatic Carbon', ' OH [hydroxy, aromatic at...
# 3      DTXSID2044347  [' CH3 [aliphatic carbon]', 'Aromatic Carbon',...
# 4      DTXSID4025745  [' CH2 [aliphatic carbon]', ' CL [chlorine, al...
# ...              ...                                                ...
# 6963   DTXSID3044752  [' CH2 [aliphatic carbon]', '=CH2 [olefinic ca...
# 6964  DTXSID80244288  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6965   DTXSID0022143  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6966   DTXSID6020303  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6967   DTXSID2025395  [' CH3 [aliphatic carbon]', ' NH [aliphatic at...
#
# [6968 rows x 8 columns]

# %%
aim_predictions = aim_predictions.drop(['Unnamed: 0'] , axis =1)

# %%
aim_predictions
# Out:
#         Y_true    Y_pred      Diff  residual       mse          dtxsid  \
# 0    -0.465339 -0.329968  0.135371  0.135371  0.018325   DTXSID5020281
# 1    -0.734786 -0.842910  0.108124 -0.108124  0.011691   DTXSID8020961
# 2    -0.087091 -0.569759  0.482668 -0.482668  0.232969   DTXSID0021834
# 3    -1.058925 -1.143505  0.084580 -0.084580  0.007154   DTXSID2044347
# 4    -1.022972 -0.786114  0.236858  0.236858  0.056102   DTXSID4025745
# ...        ...       ...       ...       ...       ...             ...
# 6963 -0.184418 -0.580946  0.396529 -0.396529  0.157235   DTXSID3044752
# 6964  1.942702  0.015562  1.927141 -1.927141  3.713872  DTXSID80244288
# 6965 -0.283519 -1.318011  1.034492 -1.034492  1.070173   DTXSID0022143
# 6966 -0.579302 -0.640617  0.061316 -0.061316  0.003760   DTXSID6020303
# 6967 -0.719993 -0.637765  0.082229  0.082229  0.006762   DTXSID2025395
#
#                                                aim_list
# 0     ['Aromatic Carbon', ' CL [chlorine, aromatic a...
# 1     ['Aromatic Carbon', ' N [aliphatic N, one arom...
# 2     ['Aromatic Carbon', ' OH [hydroxy, aromatic at...
# 3     [' CH3 [aliphatic carbon]', 'Aromatic Carbon',...
# 4     [' CH2 [aliphatic carbon]', ' CL [chlorine, al...
# ...                                                 ...
# 6963  [' CH2 [aliphatic carbon]', '=CH2 [olefinic ca...
# 6964  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6965  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6966  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6967  [' CH3 [aliphatic carbon]', ' NH [aliphatic at...
#
# [6968 rows x 7 columns]

# %%
from collections import Counter
import re

# %%
AIM_FP = pd.read_csv(raw_dir+'CHM0_apr14_aim.txt',sep=';')
AIM_FP = AIM_FP[AIM_FP['M_CORINA_SYMPHONY_ERRORS_[STRING]'] == 'No errors']
AIM_FP = AIM_FP.iloc[:,0:-2]
AIM_FP = AIM_FP.set_index('M_NAME').rename_axis(index=None)

print(AIM_FP.shape)
# # Remove duplicates (FOR AIM)
## WARNING:
## 5/5/22 -- this MIGHT not working properly 
# ex: 341C and 71E are the same
## checking the duplicates 


col_names = []
for i in AIM_FP.columns:
    col_names.append(i.split('.')[0])    
mylist = Counter(col_names)
duplicate_list= {key: value for key, value in mylist.items() if value > 1}

len_dict = len(duplicate_list)
sum_dict = sum(duplicate_list.values())
print(f'{sum_dict-len_dict} columns to be removed')

cols = []
for i in AIM_FP.columns:
    if i.split('.')[0] in duplicate_list.keys():
        cols.append(i)
        
df_dupes =AIM_FP[cols].copy()
for i,col in enumerate(df_dupes):
    col_1 = df_dupes.iloc[:,i].name.split('.')[0]
    # Match columns which are duplicates (e.g. Mercury [Measured] and Mercury [Measured].1 ) by name
    for j, col2 in enumerate(df_dupes):
        col_2 = df_dupes.iloc[:,j].name.split('.')[0]
            # If match, then column values will be updated to maximum value across the two columns for each row
        if col_1 == col_2:
            df_dupes[col] = df_dupes[[col,col2]].max(axis=1)
    
    
    
n_before = AIM_FP.shape[1]
for col in df_dupes:
    # Remove duplicate columns which are not the first (indicated by ending in  .[1-9])
    if re.search('\.[1-9]$',col) is not None:
        AIM_FP = AIM_FP.drop(columns=[col])
    else:
        AIM_FP[col] = df_dupes[col]
    
    

n_after = AIM_FP.shape[1]

print(f'{n_before-n_after} columns removed')


AIM_FP = AIM_FP.dropna(axis=1)
print(AIM_FP.shape)
AIM_FP.head()
# Out:
# (6972, 902)
# 117 columns to be removed
# 117 columns removed
# (6972, 785)
#                 CH3 [aliphatic carbon]   CH2 [aliphatic carbon]  \
# DTXSID5020281                        0                        0
# DTXSID8020961                        0                        0
# DTXSID0021834                        0                        0
# DTXSID2044347                        1                        0
# DTXSID4025745                        0                        1
#
#                 CH [aliphatic carbon]  C [aliphatic carbon No H, not tert]  \
# DTXSID5020281                       0                                    0
# DTXSID8020961                       0                                    0
# DTXSID0021834                       0                                    0
# DTXSID2044347                       0                                    0
# DTXSID4025745                       0                                    0
#
#                =CH2 [olefinic carbon]  =CH or =C [olefinc carbon]  \
# DTXSID5020281                       0                           0
# DTXSID8020961                       0                           0
# DTXSID0021834                       0                           0
# DTXSID2044347                       0                           0
# DTXSID4025745                       0                           0
#
#                #C [acetylenic carbon]   OH [hydroxy, aliphatic attach]  \
# DTXSID5020281                       0                                0
# DTXSID8020961                       0                                0
# DTXSID0021834                       0                                0
# DTXSID2044347                       0                                0
# DTXSID4025745                       0                                0
#
#                 O [oxygen, aliphatic attach]   NH2 [aliphatic attach]  ...  \
# DTXSID5020281                              0                        0  ...
# DTXSID8020961                              0                        0  ...
# DTXSID0021834                              0                        0  ...
# DTXSID2044347                              0                        0  ...
# DTXSID4025745                              0                        0  ...
#
#                N CH=N OH [oxime type] correction  \
# DTXSID5020281                                  0
# DTXSID8020961                                  0
# DTXSID0021834                                  0
# DTXSID2044347                                  0
# DTXSID4025745                                  0
#
#                Ring rx: OH ortho to C=N N carbon  \
# DTXSID5020281                                  0
# DTXSID8020961                                  0
# DTXSID0021834                                  0
# DTXSID2044347                                  0
# DTXSID4025745                                  0
#
#                =C (C#N) C#N [dicyano] correction  \
# DTXSID5020281                                  0
# DTXSID8020961                                  0
# DTXSID0021834                                  0
# DTXSID2044347                                  0
# DTXSID4025745                                  0
#
#                Aromatic nitrogen C C(=S) N struct corr.  \
# DTXSID5020281                                         0
# DTXSID8020961                                         0
# DTXSID0021834                                         0
# DTXSID2044347                                         0
# DTXSID4025745                                         0
#
#                Cyclic ketoxime(>C=N OH) [1 olefin attach]  \
# DTXSID5020281                                           0
# DTXSID8020961                                           0
# DTXSID0021834                                           0
# DTXSID2044347                                           0
# DTXSID4025745                                           0
#
#                C=N O sulfur(aliphatic) [iminoxy] correc  \
# DTXSID5020281                                         0
# DTXSID8020961                                         0
# DTXSID0021834                                         0
# DTXSID2044347                                         0
# DTXSID4025745                                         0
#
#                 S N( C(=O) C) C(=O) C struct correction  \
# DTXSID5020281                                         0
# DTXSID8020961                                         0
# DTXSID0021834                                         0
# DTXSID2044347                                         0
# DTXSID4025745                                         0
#
#                 Sulfur(+4) charged halide type  \
# DTXSID5020281                                0
# DTXSID8020961                                0
# DTXSID0021834                                0
# DTXSID2044347                                0
# DTXSID4025745                                0
#
#                Ring rx: S=P(O)(O)O / 5 mem (2 nitrogen)  \
# DTXSID5020281                                         0
# DTXSID8020961                                         0
# DTXSID0021834                                         0
# DTXSID2044347                                         0
# DTXSID4025745                                         0
#
#                O=P( O)( O) C OH correction
# DTXSID5020281                            0
# DTXSID8020961                            0
# DTXSID0021834                            0
# DTXSID2044347                            0
# DTXSID4025745                            0
#
# [5 rows x 785 columns]

# %%
aim_predictions
# Out:
#         Y_true    Y_pred      Diff  residual       mse          dtxsid  \
# 0    -0.465339 -0.329968  0.135371  0.135371  0.018325   DTXSID5020281
# 1    -0.734786 -0.842910  0.108124 -0.108124  0.011691   DTXSID8020961
# 2    -0.087091 -0.569759  0.482668 -0.482668  0.232969   DTXSID0021834
# 3    -1.058925 -1.143505  0.084580 -0.084580  0.007154   DTXSID2044347
# 4    -1.022972 -0.786114  0.236858  0.236858  0.056102   DTXSID4025745
# ...        ...       ...       ...       ...       ...             ...
# 6963 -0.184418 -0.580946  0.396529 -0.396529  0.157235   DTXSID3044752
# 6964  1.942702  0.015562  1.927141 -1.927141  3.713872  DTXSID80244288
# 6965 -0.283519 -1.318011  1.034492 -1.034492  1.070173   DTXSID0022143
# 6966 -0.579302 -0.640617  0.061316 -0.061316  0.003760   DTXSID6020303
# 6967 -0.719993 -0.637765  0.082229  0.082229  0.006762   DTXSID2025395
#
#                                                aim_list
# 0     ['Aromatic Carbon', ' CL [chlorine, aromatic a...
# 1     ['Aromatic Carbon', ' N [aliphatic N, one arom...
# 2     ['Aromatic Carbon', ' OH [hydroxy, aromatic at...
# 3     [' CH3 [aliphatic carbon]', 'Aromatic Carbon',...
# 4     [' CH2 [aliphatic carbon]', ' CL [chlorine, al...
# ...                                                 ...
# 6963  [' CH2 [aliphatic carbon]', '=CH2 [olefinic ca...
# 6964  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6965  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6966  [' CH3 [aliphatic carbon]', ' CH2 [aliphatic c...
# 6967  [' CH3 [aliphatic carbon]', ' NH [aliphatic at...
#
# [6968 rows x 7 columns]

# %%
cols2 = {k:v for k,v in enumerate(AIM_FP.columns)}

# %%
FPs2 = {}
for i,group in AIM_FP.iterrows():
    a = np.where(group.values ==1)
    b = [cols2[e] for e in a[0]]
    FPs2[i] =b

# %%
AIM_df = pd.DataFrame(list(FPs2.items()), columns = ['dtxsid', 'aim_list2'])

# %%
AIM_df['aim_list2'][0]
# Out:
# ['Aromatic Carbon',
#  ' CL [chlorine, aromatic attach]',
#  ' NO2 [nitro, aromatic attach]']

# %%
aim_predictions.shape
# Out:
# (6968, 7)

# %%
aim_predictions = pd.merge(aim_predictions, AIM_df, on = 'dtxsid', how = 'left')

# %%
aim_predictions = aim_predictions.drop(['aim_list'], axis = 1)

# %%
aim_predictions.columns = ['Y_true', 'Y_pred', 'Diff', 'residual', 'mse', 'dtxsid', 'aim_list']

# %%
aim_predictions
# Out:
#         Y_true    Y_pred      Diff  residual       mse          dtxsid  \
# 0    -0.465339 -0.329968  0.135371  0.135371  0.018325   DTXSID5020281
# 1    -0.734786 -0.842910  0.108124 -0.108124  0.011691   DTXSID8020961
# 2    -0.087091 -0.569759  0.482668 -0.482668  0.232969   DTXSID0021834
# 3    -1.058925 -1.143505  0.084580 -0.084580  0.007154   DTXSID2044347
# 4    -1.022972 -0.786114  0.236858  0.236858  0.056102   DTXSID4025745
# ...        ...       ...       ...       ...       ...             ...
# 6963 -0.184418 -0.580946  0.396529 -0.396529  0.157235   DTXSID3044752
# 6964  1.942702  0.015562  1.927141 -1.927141  3.713872  DTXSID80244288
# 6965 -0.283519 -1.318011  1.034492 -1.034492  1.070173   DTXSID0022143
# 6966 -0.579302 -0.640617  0.061316 -0.061316  0.003760   DTXSID6020303
# 6967 -0.719993 -0.637765  0.082229  0.082229  0.006762   DTXSID2025395
#
#                                                aim_list
# 0     [Aromatic Carbon,  CL [chlorine, aromatic atta...
# 1     [Aromatic Carbon,  N [aliphatic N, one aromati...
# 2     [Aromatic Carbon,  OH [hydroxy, aromatic attac...
# 3     [ CH3 [aliphatic carbon], Aromatic Carbon,  O ...
# 4     [ CH2 [aliphatic carbon],  CL [chlorine, aliph...
# ...                                                 ...
# 6963  [ CH2 [aliphatic carbon], =CH2 [olefinic carbo...
# 6964  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb...
# 6965  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb...
# 6966  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb...
# 6967  [ CH3 [aliphatic carbon],  NH [aliphatic attac...
#
# [6968 rows x 7 columns]

# %%
aim_predictions = aim_predictions[['Y_true', 'Y_pred', 'Diff', 'dtxsid', 'aim_list']]

# %%
df3 = pd.merge(aim_predictions,txp_predictions,how='inner',on='dtxsid')

# %%
df3 = pd.merge(df,df3,how='inner',on='dtxsid')
df3 = df3.rename(columns={'Y_pred_x':'Y_pred_aim','Diff_x':'Diff_aim','Y_pred_y':'Y_pred_tox','Diff_y':'Diff_tox'})

# %%
df3 = df3.drop(columns = 'Y_true_x')

# %%
df3.rename(columns = {'Y_true_y': 'Y_true'}, inplace = True)

# %%
df3.name = 'full'

# %%
df3.head()
# Out:
#           dtxsid                                class            subclass  \
# 0  DTXSID5020281  benzene and substituted derivatives       nitrobenzenes
# 1  DTXSID8020961  benzene and substituted derivatives       nitrobenzenes
# 2  DTXSID0021834                              phenols        nitrophenols
# 3  DTXSID2044347               organooxygen compounds  carbonyl compounds
# 4  DTXSID4025745  benzene and substituted derivatives       nitrobenzenes
#
#    Y_pred_aim  Diff_aim                                           aim_list  \
# 0   -0.329968  0.135371  [Aromatic Carbon,  CL [chlorine, aromatic atta...
# 1   -0.842910  0.108124  [Aromatic Carbon,  N [aliphatic N, one aromati...
# 2   -0.569759  0.482668  [Aromatic Carbon,  OH [hydroxy, aromatic attac...
# 3   -1.143505  0.084580  [ CH3 [aliphatic carbon], Aromatic Carbon,  O ...
# 4   -0.786114  0.236858  [ CH2 [aliphatic carbon],  CL [chlorine, aliph...
#
#      Y_true  Y_pred_tox  Diff_tox  \
# 0 -0.465339   -0.346871  0.118469
# 1 -0.734786   -0.838397  0.103611
# 2 -0.087091   -0.020099  0.066992
# 3 -1.058925   -1.077005  0.018080
# 4 -1.022972   -0.927933  0.095039
#
#                                             tox_list
# 0  [bond:CX_halide_aromatic-X_generic, bond:N(=O)...
# 1  [bond:CN_amine_aromatic_generic, bond:CN_amine...
# 2  [bond:COH_alcohol_aromatic, bond:COH_alcohol_a...
# 3  [bond:C=O_carbonyl_ab-unsaturated_generic, bon...
# 4  [bond:CX_halide_alkyl-X_aromatic_alkane, bond:...

# %%
#df3

# %%
'''df_tox = pd.read_pickle('../Inputs/toxprint_5_11_22.pkl')
df_tox = df_tox.reset_index()
df_tox = df_tox.rename(columns={'index':'dtxsid'})

df_aim = pd.read_pickle('../Inputs/aim_5_11_22.pkl')
df_aim = df_aim.reset_index()
df_aim = df_aim.drop(columns=['Y_true'])
df_aim= df_aim.rename(columns={'index':'dtxsid'})


df3 = pd.merge(df_aim,df_tox,how='inner',on='dtxsid')
df3 = pd.merge(df,df3,how='inner',on='dtxsid')
df3 = df3.rename(columns={'Y_pred_x':'Y_pred_aim','Diff_x':'Diff_aim','Y_pred_y':'Y_pred_tox','Diff_y':'Diff_tox'})
df3.to_pickle('df_combined.pkl')
df3.name = 'full'
df3.head(1)
# Out:
#   Input In [45]
#     df3.head(1)
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# ## Calculate stats for each group
#
# With the above created dataframe, we can now calculate additional stats for each group

# %%
from sklearn.metrics import r2_score

def class_errors(df):
    diffs = []
    for i in grps:
        if i in chem_classes:
            df2 = df[df['class'] == i]
        else:
            df2 = df[df['subclass'] == i]

        err_tox = df2['Diff_tox'].mean()
        err_aim = df2['Diff_aim'].mean()
        true = df2['Y_true'].mean()
        true_range = df2['Y_true'].max()-df2['Y_true'].min()


        num = len(df2['Diff_tox'])
        if num > 20:
            perf_tox =  r2_score(df2['Y_true'],df2['Y_pred_tox'])
            perf_aim =  r2_score(df2['Y_true'],df2['Y_pred_aim'])
        else: 
            perf_tox=0
            perf_aim = 0
        diffs.append([err_tox,err_aim,true,true_range,num,perf_tox,perf_aim])
        
    df3 = pd.DataFrame.from_dict(dict(zip(grps,diffs))).T
    return df3

# %%
df_grps = class_errors(df3)
df_grps = df_grps.rename(columns={0:'Error_tox',1:'Error_aim',2:'True',3:'True_range',4:'N Struc',5:'r2_tox',6:'r2_aim'})
df_grps = df_grps[df_grps['N Struc'] > 20].copy()
df_grps['diff_err'] = df_grps['Error_tox'] -df_grps['Error_aim']

#df_grps.to_pickle('grp_df.pkl')
df_grps.sort_values(by=['diff_err'])

## We see that the biggest gaps in performance are the following groups:
## Toxprint Outperorms:
    ## alpha-halocarboxylic acids and derivatives (0.33)
    ## carbohydrates and carbohydrate conjugates   (0.24)
## AIM Outperforms
    ## isoindoles and derivatives (0.21)
    ## Benzodioxoles       (0.15)
# Out:
#                                                 Error_tox  Error_aim  \
# alpha-halocarboxylic acids and derivatives       0.607868   0.932742
# trifluoromethylbenzenes                          0.469786   0.713086
# carbohydrates and carbohydrate conjugates        0.454338   0.660842
# organic dithiophosphoric acids and derivatives   0.735490   0.931329
# benzenesulfonic acids and derivatives            0.305711   0.473257
# ...                                                   ...        ...
# benzenesulfonyl compounds                        0.591777   0.515636
# organic thiophosphoric acids and derivatives     0.745701   0.652578
# thioethers                                       0.683818   0.569910
# isoindoles and derivatives                       0.746103   0.610287
# benzodioxoles                                    0.517264   0.347919
#
#                                                     True  True_range  N Struc  \
# alpha-halocarboxylic acids and derivatives     -0.382454    4.707719     21.0
# trifluoromethylbenzenes                        -0.511234    2.818646     32.0
# carbohydrates and carbohydrate conjugates      -1.047618    4.117472     28.0
# organic dithiophosphoric acids and derivatives  0.560882    4.354751     44.0
# benzenesulfonic acids and derivatives          -1.107290    1.588678     26.0
# ...                                                  ...         ...      ...
# benzenesulfonyl compounds                      -0.605603    3.363983     21.0
# organic thiophosphoric acids and derivatives    0.448417    4.502745     99.0
# thioethers                                     -0.335817    4.117858     51.0
# isoindoles and derivatives                     -0.377211    3.372632     27.0
# benzodioxoles                                  -0.506258    2.766597     24.0
#
#                                                   r2_tox    r2_aim  diff_err
# alpha-halocarboxylic acids and derivatives      0.377178 -0.421278 -0.324874
# trifluoromethylbenzenes                         0.081392 -1.424368 -0.243300
# carbohydrates and carbohydrate conjugates       0.508123  0.022958 -0.206504
# organic dithiophosphoric acids and derivatives  0.529655  0.176486 -0.195839
# benzenesulfonic acids and derivatives           0.257307 -0.316190 -0.167546
# ...                                                  ...       ...       ...
# benzenesulfonyl compounds                       0.475840  0.522705  0.076142
# organic thiophosphoric acids and derivatives   -0.129169  0.192026  0.093123
# thioethers                                      0.084105  0.315603  0.113908
# isoindoles and derivatives                      0.141279  0.328820  0.135816
# benzodioxoles                                   0.184459  0.579897  0.169345
#
# [88 rows x 8 columns]

# %%
df_grps.sort_values(by = ["Error_tox", 'Error_aim'], ascending = [False, False]).to_csv(processed_dir+"ClassyFire_performance_summaries.csv")

# %%
df_grps[(df_grps['Error_tox'] > 0.5) & (df_grps['Error_aim'] < 0.5)]
# Out:
#                          Error_tox  Error_aim      True  True_range  N Struc  \
# benzodioxoles             0.517264   0.347919 -0.506258    2.766597     24.0
# benzothiazoles            0.556378   0.480254 -0.730653    2.605785     33.0
# phenyl methylcarbamates   0.549053   0.477193  0.237122    2.401843     48.0
#
#                            r2_tox    r2_aim  diff_err
# benzodioxoles            0.184459  0.579897  0.169345
# benzothiazoles          -0.127888  0.058511  0.076124
# phenyl methylcarbamates -0.369807 -0.035990  0.071860

# %%
df_grps['abs_diff_err'] = np.abs(df_grps['diff_err'])

# %%
df_grps.sort_values(by = 'abs_diff_err', ascending = False)
# Out:
#                                                 Error_tox  Error_aim  \
# alpha-halocarboxylic acids and derivatives       0.607868   0.932742
# trifluoromethylbenzenes                          0.469786   0.713086
# carbohydrates and carbohydrate conjugates        0.454338   0.660842
# organic dithiophosphoric acids and derivatives   0.735490   0.931329
# benzodioxoles                                    0.517264   0.347919
# ...                                                   ...        ...
# organic phosphonic acids and derivatives         0.667395   0.668926
# stilbenes                                        0.352245   0.353521
# allyl-type 1,3-dipolar organic compounds         0.655618   0.656266
# diazines                                         0.511916   0.511457
# tetracarboxylic acids and derivatives            0.381659   0.381539
#
#                                                     True  True_range  N Struc  \
# alpha-halocarboxylic acids and derivatives     -0.382454    4.707719     21.0
# trifluoromethylbenzenes                        -0.511234    2.818646     32.0
# carbohydrates and carbohydrate conjugates      -1.047618    4.117472     28.0
# organic dithiophosphoric acids and derivatives  0.560882    4.354751     44.0
# benzodioxoles                                  -0.506258    2.766597     24.0
# ...                                                  ...         ...      ...
# organic phosphonic acids and derivatives       -0.405251    4.479084     44.0
# stilbenes                                      -0.769825    2.323996     33.0
# allyl-type 1,3-dipolar organic compounds       -0.396500    2.627296     23.0
# diazines                                       -0.358885    4.935572    115.0
# tetracarboxylic acids and derivatives          -0.993089    2.656175     25.0
#
#                                                   r2_tox    r2_aim  diff_err  \
# alpha-halocarboxylic acids and derivatives      0.377178 -0.421278 -0.324874
# trifluoromethylbenzenes                         0.081392 -1.424368 -0.243300
# carbohydrates and carbohydrate conjugates       0.508123  0.022958 -0.206504
# organic dithiophosphoric acids and derivatives  0.529655  0.176486 -0.195839
# benzodioxoles                                   0.184459  0.579897  0.169345
# ...                                                  ...       ...       ...
# organic phosphonic acids and derivatives        0.430095  0.371154 -0.001531
# stilbenes                                       0.118868  0.140811 -0.001275
# allyl-type 1,3-dipolar organic compounds       -0.311596 -0.038373 -0.000647
# diazines                                        0.460120  0.471892  0.000459
# tetracarboxylic acids and derivatives          -0.075169 -0.063351  0.000120
#
#                                                 abs_diff_err
# alpha-halocarboxylic acids and derivatives          0.324874
# trifluoromethylbenzenes                             0.243300
# carbohydrates and carbohydrate conjugates           0.206504
# organic dithiophosphoric acids and derivatives      0.195839
# benzodioxoles                                       0.169345
# ...                                                      ...
# organic phosphonic acids and derivatives            0.001531
# stilbenes                                           0.001275
# allyl-type 1,3-dipolar organic compounds            0.000647
# diazines                                            0.000459
# tetracarboxylic acids and derivatives               0.000120
#
# [88 rows x 9 columns]

# %%
tox_grps = df_grps[df_grps['r2_tox'] > 0.477].sort_values('r2_tox', ascending = False).index

# %%
df_grps[df_grps['r2_tox'] > 0.477].sort_values('r2_tox', ascending = False)
# Out:
#                                                 Error_tox  Error_aim  \
# benzimidazoles                                   0.396620   0.430220
# naphthalenes                                     0.396824   0.432969
# fatty acid esters                                0.366372   0.372044
# nitrobenzenes                                    0.466485   0.446182
# fatty alcohols                                   0.388506   0.351629
# prenol lipids                                    0.431741   0.467365
# organic carbonic acids and derivatives           0.397058   0.439051
# organic dithiophosphoric acids and derivatives   0.735490   0.931329
# ethers                                           0.349063   0.381002
# carbohydrates and carbohydrate conjugates        0.454338   0.660842
# organic phosphoric acids and derivatives         0.649293   0.679351
#
#                                                     True  True_range  N Struc  \
# benzimidazoles                                  0.978775    4.658377    148.0
# naphthalenes                                   -0.730803    5.781051    122.0
# fatty acid esters                              -0.796435    4.059256    118.0
# nitrobenzenes                                  -0.317930    4.107888     97.0
# fatty alcohols                                 -1.206899    3.583906     30.0
# prenol lipids                                  -0.796269    4.619478    122.0
# organic carbonic acids and derivatives         -0.494333    3.229101     67.0
# organic dithiophosphoric acids and derivatives  0.560882    4.354751     44.0
# ethers                                         -1.059734    3.612642    132.0
# carbohydrates and carbohydrate conjugates      -1.047618    4.117472     28.0
# organic phosphoric acids and derivatives        0.043533    4.117943     61.0
#
#                                                   r2_tox    r2_aim  diff_err  \
# benzimidazoles                                  0.681144  0.652066 -0.033600
# naphthalenes                                    0.680218  0.633588 -0.036145
# fatty acid esters                               0.656250  0.633516 -0.005673
# nitrobenzenes                                   0.609024  0.651297  0.020303
# fatty alcohols                                  0.597109  0.552406  0.036877
# prenol lipids                                   0.556581  0.486157 -0.035623
# organic carbonic acids and derivatives          0.540963  0.441328 -0.041994
# organic dithiophosphoric acids and derivatives  0.529655  0.176486 -0.195839
# ethers                                          0.518158  0.479673 -0.031939
# carbohydrates and carbohydrate conjugates       0.508123  0.022958 -0.206504
# organic phosphoric acids and derivatives        0.479026  0.435065 -0.030057
#
#                                                 abs_diff_err
# benzimidazoles                                      0.033600
# naphthalenes                                        0.036145
# fatty acid esters                                   0.005673
# nitrobenzenes                                       0.020303
# fatty alcohols                                      0.036877
# prenol lipids                                       0.035623
# organic carbonic acids and derivatives              0.041994
# organic dithiophosphoric acids and derivatives      0.195839
# ethers                                              0.031939
# carbohydrates and carbohydrate conjugates           0.206504
# organic phosphoric acids and derivatives            0.030057

# %%
aim_grps = df_grps[df_grps['r2_aim'] > 0.44].sort_values('r2_aim', ascending = False).index

# %%
df_grps[df_grps['r2_aim'] > 0.44].sort_values('r2_aim', ascending = False)
# Out:
#                                         Error_tox  Error_aim      True  \
# benzimidazoles                           0.396620   0.430220  0.978775
# nitrobenzenes                            0.466485   0.446182 -0.317930
# naphthalenes                             0.396824   0.432969 -0.730803
# fatty acid esters                        0.366372   0.372044 -0.796435
# aniline and substituted anilines         0.488551   0.424937 -0.470510
# benzodioxoles                            0.517264   0.347919 -0.506258
# fatty alcohols                           0.388506   0.351629 -1.206899
# benzenesulfonyl compounds                0.591777   0.515636 -0.605603
# prenol lipids                            0.431741   0.467365 -0.796269
# ethers                                   0.349063   0.381002 -1.059734
# anthracenes                              0.322071   0.294114 -0.822171
# diazines                                 0.511916   0.511457 -0.358885
# steroids and steroid derivatives         0.682228   0.695965  0.185708
# organic carbonic acids and derivatives   0.397058   0.439051 -0.494333
#
#                                         True_range  N Struc    r2_tox  \
# benzimidazoles                            4.658377    148.0  0.681144
# nitrobenzenes                             4.107888     97.0  0.609024
# naphthalenes                              5.781051    122.0  0.680218
# fatty acid esters                         4.059256    118.0  0.656250
# aniline and substituted anilines          4.214571     57.0  0.459155
# benzodioxoles                             2.766597     24.0  0.184459
# fatty alcohols                            3.583906     30.0  0.597109
# benzenesulfonyl compounds                 3.363983     21.0  0.475840
# prenol lipids                             4.619478    122.0  0.556581
# ethers                                    3.612642    132.0  0.518158
# anthracenes                               2.094611     30.0  0.384586
# diazines                                  4.935572    115.0  0.460120
# steroids and steroid derivatives          4.761707     41.0  0.446131
# organic carbonic acids and derivatives    3.229101     67.0  0.540963
#
#                                           r2_aim  diff_err  abs_diff_err
# benzimidazoles                          0.652066 -0.033600      0.033600
# nitrobenzenes                           0.651297  0.020303      0.020303
# naphthalenes                            0.633588 -0.036145      0.036145
# fatty acid esters                       0.633516 -0.005673      0.005673
# aniline and substituted anilines        0.600851  0.063615      0.063615
# benzodioxoles                           0.579897  0.169345      0.169345
# fatty alcohols                          0.552406  0.036877      0.036877
# benzenesulfonyl compounds               0.522705  0.076142      0.076142
# prenol lipids                           0.486157 -0.035623      0.035623
# ethers                                  0.479673 -0.031939      0.031939
# anthracenes                             0.477452  0.027957      0.027957
# diazines                                0.471892  0.000459      0.000459
# steroids and steroid derivatives        0.462716 -0.013737      0.013737
# organic carbonic acids and derivatives  0.441328 -0.041994      0.041994

# %%
[e for e in aim_grps if e not in tox_grps]
# Out:
# ['aniline and substituted anilines',
#  'benzodioxoles',
#  'benzenesulfonyl compounds',
#  'anthracenes',
#  'diazines',
#  'steroids and steroid derivatives']

# %%
df_grps[df_grps['r2_aim'] < 0.44].sort_values('r2_aim', ascending = False).index[-5:]
# Out:
# Index(['alpha-halocarboxylic acids and derivatives', 'benzenesulfonamides',
#        'nitrogen mustard compounds', 'phenylmethylamines',
#        'trifluoromethylbenzenes'],
#       dtype='object')

# %%
df_grps[df_grps['r2_aim'] < 0.44].sort_values('r2_aim', ascending = False)
# Out:
#                                             Error_tox  Error_aim      True  \
# organic phosphoric acids and derivatives     0.649293   0.679351  0.043533
# organic phosphonic acids and derivatives     0.667395   0.668926 -0.405251
# anilides                                     0.406115   0.414982 -0.599201
# xylenes                                      0.620962   0.629203 -0.505436
# isoindoles and derivatives                   0.746103   0.610287 -0.377211
# ...                                               ...        ...       ...
# alpha-halocarboxylic acids and derivatives   0.607868   0.932742 -0.382454
# benzenesulfonamides                          0.389669   0.460109 -0.864773
# nitrogen mustard compounds                   0.581727   0.638400  0.845689
# phenylmethylamines                           0.534533   0.540869 -0.692858
# trifluoromethylbenzenes                      0.469786   0.713086 -0.511234
#
#                                             True_range  N Struc    r2_tox  \
# organic phosphoric acids and derivatives      4.117943     61.0  0.479026
# organic phosphonic acids and derivatives      4.479084     44.0  0.430095
# anilides                                      3.771435    102.0  0.418116
# xylenes                                       4.313077     21.0  0.314231
# isoindoles and derivatives                    3.372632     27.0  0.141279
# ...                                                ...      ...       ...
# alpha-halocarboxylic acids and derivatives    4.707719     21.0  0.377178
# benzenesulfonamides                           2.397570     59.0 -0.107345
# nitrogen mustard compounds                    2.870903     22.0 -0.396446
# phenylmethylamines                            1.594488     21.0 -1.087412
# trifluoromethylbenzenes                       2.818646     32.0  0.081392
#
#                                               r2_aim  diff_err  abs_diff_err
# organic phosphoric acids and derivatives    0.435065 -0.030057      0.030057
# organic phosphonic acids and derivatives    0.371154 -0.001531      0.001531
# anilides                                    0.359928 -0.008867      0.008867
# xylenes                                     0.338655 -0.008241      0.008241
# isoindoles and derivatives                  0.328820  0.135816      0.135816
# ...                                              ...       ...           ...
# alpha-halocarboxylic acids and derivatives -0.421278 -0.324874      0.324874
# benzenesulfonamides                        -0.427501 -0.070440      0.070440
# nitrogen mustard compounds                 -0.900646 -0.056673      0.056673
# phenylmethylamines                         -0.969916 -0.006335      0.006335
# trifluoromethylbenzenes                    -1.424368 -0.243300      0.243300
#
# [74 rows x 9 columns]

# %%
df_grps[df_grps['r2_tox'] < 0.477].sort_values('r2_tox', ascending = False)
# Out:
#                                           Error_tox  Error_aim      True  \
# benzenesulfonyl compounds                  0.591777   0.515636 -0.605603
# diazines                                   0.511916   0.511457 -0.358885
# aniline and substituted anilines           0.488551   0.424937 -0.470510
# steroids and steroid derivatives           0.682228   0.695965  0.185708
# carboxylic acid derivatives                0.497175   0.557603 -0.972463
# ...                                             ...        ...       ...
# allyl-type 1,3-dipolar organic compounds   0.655618   0.656266 -0.396500
# phenyl methylcarbamates                    0.549053   0.477193  0.237122
# nitrogen mustard compounds                 0.581727   0.638400  0.845689
# triazines                                  0.384406   0.369066 -0.741802
# phenylmethylamines                         0.534533   0.540869 -0.692858
#
#                                           True_range  N Struc    r2_tox  \
# benzenesulfonyl compounds                   3.363983     21.0  0.475840
# diazines                                    4.935572    115.0  0.460120
# aniline and substituted anilines            4.214571     57.0  0.459155
# steroids and steroid derivatives            4.761707     41.0  0.446131
# carboxylic acid derivatives                 4.407261    136.0  0.438063
# ...                                              ...      ...       ...
# allyl-type 1,3-dipolar organic compounds    2.627296     23.0 -0.311596
# phenyl methylcarbamates                     2.401843     48.0 -0.369807
# nitrogen mustard compounds                  2.870903     22.0 -0.396446
# triazines                                   1.983938     53.0 -0.526252
# phenylmethylamines                          1.594488     21.0 -1.087412
#
#                                             r2_aim  diff_err  abs_diff_err
# benzenesulfonyl compounds                 0.522705  0.076142      0.076142
# diazines                                  0.471892  0.000459      0.000459
# aniline and substituted anilines          0.600851  0.063615      0.063615
# steroids and steroid derivatives          0.462716 -0.013737      0.013737
# carboxylic acid derivatives               0.281725 -0.060429      0.060429
# ...                                            ...       ...           ...
# allyl-type 1,3-dipolar organic compounds -0.038373 -0.000647      0.000647
# phenyl methylcarbamates                  -0.035990  0.071860      0.071860
# nitrogen mustard compounds               -0.900646 -0.056673      0.056673
# triazines                                -0.366271  0.015340      0.015340
# phenylmethylamines                       -0.969916 -0.006335      0.006335
#
# [77 rows x 9 columns]

# %%
df_grps[df_grps['r2_tox'] < 0.477].sort_values('r2_tox', ascending = False).index[-5:]
# Out:
# Index(['allyl-type 1,3-dipolar organic compounds', 'phenyl methylcarbamates',
#        'nitrogen mustard compounds', 'triazines', 'phenylmethylamines'],
#       dtype='object')

# %%
df_grps.sort_values(by = 'abs_diff_err', ascending = False)
# Out:
#                                                 Error_tox  Error_aim  \
# alpha-halocarboxylic acids and derivatives       0.607868   0.932742
# trifluoromethylbenzenes                          0.469786   0.713086
# carbohydrates and carbohydrate conjugates        0.454338   0.660842
# organic dithiophosphoric acids and derivatives   0.735490   0.931329
# benzodioxoles                                    0.517264   0.347919
# ...                                                   ...        ...
# organic phosphonic acids and derivatives         0.667395   0.668926
# stilbenes                                        0.352245   0.353521
# allyl-type 1,3-dipolar organic compounds         0.655618   0.656266
# diazines                                         0.511916   0.511457
# tetracarboxylic acids and derivatives            0.381659   0.381539
#
#                                                     True  True_range  N Struc  \
# alpha-halocarboxylic acids and derivatives     -0.382454    4.707719     21.0
# trifluoromethylbenzenes                        -0.511234    2.818646     32.0
# carbohydrates and carbohydrate conjugates      -1.047618    4.117472     28.0
# organic dithiophosphoric acids and derivatives  0.560882    4.354751     44.0
# benzodioxoles                                  -0.506258    2.766597     24.0
# ...                                                  ...         ...      ...
# organic phosphonic acids and derivatives       -0.405251    4.479084     44.0
# stilbenes                                      -0.769825    2.323996     33.0
# allyl-type 1,3-dipolar organic compounds       -0.396500    2.627296     23.0
# diazines                                       -0.358885    4.935572    115.0
# tetracarboxylic acids and derivatives          -0.993089    2.656175     25.0
#
#                                                   r2_tox    r2_aim  diff_err  \
# alpha-halocarboxylic acids and derivatives      0.377178 -0.421278 -0.324874
# trifluoromethylbenzenes                         0.081392 -1.424368 -0.243300
# carbohydrates and carbohydrate conjugates       0.508123  0.022958 -0.206504
# organic dithiophosphoric acids and derivatives  0.529655  0.176486 -0.195839
# benzodioxoles                                   0.184459  0.579897  0.169345
# ...                                                  ...       ...       ...
# organic phosphonic acids and derivatives        0.430095  0.371154 -0.001531
# stilbenes                                       0.118868  0.140811 -0.001275
# allyl-type 1,3-dipolar organic compounds       -0.311596 -0.038373 -0.000647
# diazines                                        0.460120  0.471892  0.000459
# tetracarboxylic acids and derivatives          -0.075169 -0.063351  0.000120
#
#                                                 abs_diff_err
# alpha-halocarboxylic acids and derivatives          0.324874
# trifluoromethylbenzenes                             0.243300
# carbohydrates and carbohydrate conjugates           0.206504
# organic dithiophosphoric acids and derivatives      0.195839
# benzodioxoles                                       0.169345
# ...                                                      ...
# organic phosphonic acids and derivatives            0.001531
# stilbenes                                           0.001275
# allyl-type 1,3-dipolar organic compounds            0.000647
# diazines                                            0.000459
# tetracarboxylic acids and derivatives               0.000120
#
# [88 rows x 9 columns]

# %%
df_grps[df_grps.index =='isoindoles and derivatives']
# Out:
#                             Error_tox  Error_aim      True  True_range  \
# isoindoles and derivatives   0.746103   0.610287 -0.377211    3.372632
#
#                             N Struc    r2_tox   r2_aim  diff_err  abs_diff_err
# isoindoles and derivatives     27.0  0.141279  0.32882  0.135816      0.135816

# %% [markdown]
# ## PLotting group distribution
#
# We want to see how variable toxicity of chemicals in our groups are
#
# If a group contains similar structures, then it should have a smaller range

# %%
def plot_grps_dist(df, filename):
    data = []
    for i in grps:
        #print(i)
        if i in chem_classes:
            df2 = df[df['class']==i]
        else:
            df2 = df[df['subclass']==i]
        if len(df2) > 20:
            Y_range = df2['Y_true'].max()-df2['Y_true'].min()
            Y_median = df2['Y_true'].median()
            data.append([i, df2['Y_true'],Y_median, Y_range,len(df2)])
           
    plt.style.use('ggplot')
    fig, ax = plt.subplots(figsize=(9,20))
    
    df = pd.DataFrame(data)
    df = df.rename(columns={0: 'group', 1: 'data',2: 'median', 3:'range',4:'num_struc'})
    df = df.sort_values(by='median', ascending = False)
    
    #ax.boxplot(df, vert = False)
    ax.boxplot(df['data'], vert = False)

    ax.set_yticks(list(range(1,89)),df['group']);
    #ax.set_title('Toxicity Distribution of Groups')
    ax.set_xlabel('LD50 - logmolar')
    ax.set_ylabel('Group')
    plt.show()
    fig.savefig(figures_dir+filename, dpi = 300, bbox_inches='tight' )
        
    return df

# %%
plot_grps_dist(df3, 'Figure7.png')
# Out:
#                                              group  \
# 30                                  benzimidazoles
# 3                                        coumarans
# 18                      nitrogen mustard compounds
# 72                  organothiophosphorus compounds
# 1   organic dithiophosphoric acids and derivatives
# ..                                             ...
# 70                      fatty acids and conjugates
# 80                                          ethers
# 78                            alcohols and polyols
# 23                     carboxylic acid derivatives
# 69                                  fatty alcohols
#
#                                                  data    median     range  \
# 30  351    -1.524715
# 781    -0.730966
# 1326   -0.26...  1.171850  4.658377
# 3   1686    1.633088
# 1687    0.682982
# 1818    1.11...  1.119870  2.627021
# 18  60      0.977769
# 2444    1.274040
# 2939    0.54...  0.862736  2.870903
# 72  169     1.183447
# 825     0.865784
# 1066    2.23...  0.797637  4.171682
# 1   362    -1.589597
# 632    -1.063064
# 768     0.28...  0.640241  4.354751
# ..                                                ...       ...       ...
# 70  297    -0.415567
# 363    -0.605454
# 401    -1.26... -1.214982  2.773616
# 80  34     -1.724001
# 113    -1.677951
# 120    -2.14... -1.223337  3.612642
# 78  267    -1.346143
# 272    -1.139866
# 273    -0.10... -1.326619  3.883632
# 23  42      0.490875
# 156     0.133162
# 167    -1.47... -1.356398  4.407261
# 69  239    -1.196403
# 336    -2.062660
# 597    -1.49... -1.357122  3.583906
#
#     num_struc
# 30        148
# 3          24
# 18         22
# 72         39
# 1          44
# ..        ...
# 70         52
# 80        132
# 78         69
# 23        136
# 69         30
#
# [88 rows x 5 columns]

# %%
df_dist = plot_grps_dist(df3,'Figure7.png')
#plt.savefig(figures_dir+'Figure7.png')

# %%
df_dist.to_csv(processed_dir+'Figure7_boxplot_data_220922.csv')

# %%
df_dist
# Out:
#                                              group  \
# 30                                  benzimidazoles
# 3                                        coumarans
# 18                      nitrogen mustard compounds
# 72                  organothiophosphorus compounds
# 1   organic dithiophosphoric acids and derivatives
# ..                                             ...
# 70                      fatty acids and conjugates
# 80                                          ethers
# 78                            alcohols and polyols
# 23                     carboxylic acid derivatives
# 69                                  fatty alcohols
#
#                                                  data    median     range  \
# 30  351    -1.524715
# 781    -0.730966
# 1326   -0.26...  1.171850  4.658377
# 3   1686    1.633088
# 1687    0.682982
# 1818    1.11...  1.119870  2.627021
# 18  60      0.977769
# 2444    1.274040
# 2939    0.54...  0.862736  2.870903
# 72  169     1.183447
# 825     0.865784
# 1066    2.23...  0.797637  4.171682
# 1   362    -1.589597
# 632    -1.063064
# 768     0.28...  0.640241  4.354751
# ..                                                ...       ...       ...
# 70  297    -0.415567
# 363    -0.605454
# 401    -1.26... -1.214982  2.773616
# 80  34     -1.724001
# 113    -1.677951
# 120    -2.14... -1.223337  3.612642
# 78  267    -1.346143
# 272    -1.139866
# 273    -0.10... -1.326619  3.883632
# 23  42      0.490875
# 156     0.133162
# 167    -1.47... -1.356398  4.407261
# 69  239    -1.196403
# 336    -2.062660
# 597    -1.49... -1.357122  3.583906
#
#     num_struc
# 30        148
# 3          24
# 18         22
# 72         39
# 1          44
# ..        ...
# 70         52
# 80        132
# 78         69
# 23        136
# 69         30
#
# [88 rows x 5 columns]

# %%
df_dist['range'].median()
# Out:
# 3.249787238405

# %% [markdown]
# ## Visualize the errors
# We want to find out if there are any classes which one fingerprint set signficantly outperforms the other

# %%
plt.style.use('seaborn')
X = df_grps['Error_tox']
Y = df_grps['Error_aim']
plt.figure(figsize=(6,4))
plt.plot(X,X,color='black')
plt.scatter(X,Y)
plt.ylim([0.1,1])
plt.xlim([0.1,1])
plt.ylabel('Mean Absolute Error AIM-CSRML')
plt.xlabel('Mean Absolute Error ToxPrints')
#plt.title('Classes and Errors')
plt.savefig(figures_dir+'Figure8.png', dpi = 300)

# %%
plt.style.use('seaborn')
X = df_grps['Error_tox']
Y = df_grps['Error_aim']
plt.figure(figsize=(6,4))
plt.plot(X,X,color='black')
plt.scatter(X,Y)
X2 = X['isoindoles and derivatives']
Y2 = Y['isoindoles and derivatives']
plt.scatter(X2,Y2,color='red')
plt.ylim([0.1,1])
plt.xlim([0.1,1])
plt.ylabel('Mean Absolute Error AIM-CSRML')
plt.xlabel('Mean Absolute Error ToxPrints')
plt.savefig(figures_dir+'Figure 9.png', dpi = 300)

# %% [markdown]
# We see a positive correlation of performance between the two feature sets.
#
# Some are "well-predicted" (<0.4) while other groups are poorly predicted (>0.6)
#
# Not a significant difference in performance between the fingerprint sets for majority of groups

# %%
from collections import Counter
import numpy as np
def frag_freq(df,col_name):
    fragments = []
    for row in df[col_name]:  
        for fragment in row:
            fragments.append(fragment)

    frequency = Counter(fragments)

    for item, count in frequency.items():
        frequency[item] = np.round(frequency[item],3)
    
    df = pd.DataFrame.from_dict(frequency, orient='index', columns=[df.name])
    return df

# %%
df3
# Out:
#               dtxsid                                class  \
# 0      DTXSID5020281  benzene and substituted derivatives
# 1      DTXSID8020961  benzene and substituted derivatives
# 2      DTXSID0021834                              phenols
# 3      DTXSID2044347               organooxygen compounds
# 4      DTXSID4025745  benzene and substituted derivatives
# ...              ...                                  ...
# 6923   DTXSID3044752                          fatty acyls
# 6924  DTXSID80244288       organothiophosphorus compounds
# 6925   DTXSID0022143     carboxylic acids and derivatives
# 6926   DTXSID6020303             organonitrogen compounds
# 6927   DTXSID2025395            organometalloid compounds
#
#                            subclass  Y_pred_aim  Diff_aim  \
# 0                     nitrobenzenes   -0.329968  0.135371
# 1                     nitrobenzenes   -0.842910  0.108124
# 2                      nitrophenols   -0.569759  0.482668
# 3                carbonyl compounds   -1.143505  0.084580
# 4                     nitrobenzenes   -0.786114  0.236858
# ...                             ...         ...       ...
# 6923              fatty acid esters   -0.580946  0.396529
# 6924                            NaN    0.015562  1.927141
# 6925  acrylic acids and derivatives   -1.318011  1.034492
# 6926      quaternary ammonium salts   -0.640617  0.061316
# 6927        organosilicon compounds   -0.637765  0.082229
#
#                                                aim_list    Y_true  Y_pred_tox  \
# 0     [Aromatic Carbon,  CL [chlorine, aromatic atta... -0.465339   -0.346871
# 1     [Aromatic Carbon,  N [aliphatic N, one aromati... -0.734786   -0.838397
# 2     [Aromatic Carbon,  OH [hydroxy, aromatic attac... -0.087091   -0.020099
# 3     [ CH3 [aliphatic carbon], Aromatic Carbon,  O ... -1.058925   -1.077005
# 4     [ CH2 [aliphatic carbon],  CL [chlorine, aliph... -1.022972   -0.927933
# ...                                                 ...       ...         ...
# 6923  [ CH2 [aliphatic carbon], =CH2 [olefinic carbo... -0.184418   -1.149901
# 6924  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb...  1.942702    0.940935
# 6925  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb... -0.283519   -0.625075
# 6926  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb... -0.579302   -0.190255
# 6927  [ CH3 [aliphatic carbon],  NH [aliphatic attac... -0.719993   -0.701917
#
#       Diff_tox                                           tox_list
# 0     0.118469  [bond:CX_halide_aromatic-X_generic, bond:N(=O)...
# 1     0.103611  [bond:CN_amine_aromatic_generic, bond:CN_amine...
# 2     0.066992  [bond:COH_alcohol_aromatic, bond:COH_alcohol_a...
# 3     0.018080  [bond:C=O_carbonyl_ab-unsaturated_generic, bon...
# 4     0.095039  [bond:CX_halide_alkyl-X_aromatic_alkane, bond:...
# ...        ...                                                ...
# 6923  0.965483  [bond:C(=O)O_carboxylicEster_acyclic, bond:C(=...
# 6924  1.001768  [bond:CS_sulfide, bond:PC_phosphorus_organo_ge...
# 6925  0.341556  [bond:C(=O)O_carboxylicEster_acyclic, bond:C(=...
# 6926  0.389047  [bond:CX_halide_alkyl-Cl_ethyl, bond:CX_halide...
# 6927  0.018076  [atom:element_metal_metalloid, bond:N[!C]_amin...
#
# [6928 rows x 10 columns]

# %%
import functools

def freq_table(col_name):
    df_full = frag_freq(df3,col_name)

    dfs = [df_full]
    group_counts = [len(df3)]
    for i in grps:
        if i in chem_classes:
            df_label_i = df3[df3['class'] == i]
        else:
            df_label_i = df3[df3['subclass'] == i]
        if len(df_label_i) > 10:
            group_counts.append(len(df_label_i))
            df_label_i.name = i
            df_label = frag_freq(df_label_i,col_name)
            dfs.append(df_label)

    df = functools.reduce(lambda left,right: pd.merge(left,right,left_index=True,right_index=True,how='outer'),dfs)
    df.loc[len(df)] = group_counts
    df = df.rename(index = {(len(df)-1):"count"})
    df = df.fillna(0)
    return df

# %%
df_tox = freq_table('tox_list')
df_aim = freq_table('aim_list')

# %%
df_tox
# Out:
#                                       full  pyrrolidines  \
# atom:element_metal_group_I_II          311           0.0
# atom:element_metal_metalloid            88           0.0
# atom:element_metal_transistion_metal    22           0.0
# bond:C#N_cyano_acylcyanide               1           0.0
# bond:C#N_cyano_cyanamide                14           0.0
# ...                                    ...           ...
# ring:polycycle_bicyclo_[3.3.1]nonane     6           0.0
# ring:polycycle_bicyclo_[3.3.2]decane     5           0.0
# ring:polycycle_spiro_[4.5]decane         1           0.0
# ring:polycycle_tricyclo_adamantane       6           0.0
# count                                 6928          18.0
#
#                                       thiocarbonyl compounds  epoxides  \
# atom:element_metal_group_I_II                            0.0       0.0
# atom:element_metal_metalloid                             0.0       0.0
# atom:element_metal_transistion_metal                     0.0       0.0
# bond:C#N_cyano_acylcyanide                               0.0       0.0
# bond:C#N_cyano_cyanamide                                 0.0       0.0
# ...                                                      ...       ...
# ring:polycycle_bicyclo_[3.3.1]nonane                     0.0       0.0
# ring:polycycle_bicyclo_[3.3.2]decane                     0.0       0.0
# ring:polycycle_spiro_[4.5]decane                         0.0       0.0
# ring:polycycle_tricyclo_adamantane                       0.0       0.0
# count                                                   14.0      22.0
#
#                                       benzoxazoles  sulfonyls  \
# atom:element_metal_group_I_II                  0.0        0.0
# atom:element_metal_metalloid                   0.0        0.0
# atom:element_metal_transistion_metal           0.0        0.0
# bond:C#N_cyano_acylcyanide                     0.0        0.0
# bond:C#N_cyano_cyanamide                       0.0        0.0
# ...                                            ...        ...
# ring:polycycle_bicyclo_[3.3.1]nonane           0.0        0.0
# ring:polycycle_bicyclo_[3.3.2]decane           0.0        0.0
# ring:polycycle_spiro_[4.5]decane               0.0        0.0
# ring:polycycle_tricyclo_adamantane             0.0        0.0
# count                                         32.0       16.0
#
#                                       organochlorides  \
# atom:element_metal_group_I_II                     0.0
# atom:element_metal_metalloid                      0.0
# atom:element_metal_transistion_metal              0.0
# bond:C#N_cyano_acylcyanide                        0.0
# bond:C#N_cyano_cyanamide                          0.0
# ...                                               ...
# ring:polycycle_bicyclo_[3.3.1]nonane              0.0
# ring:polycycle_bicyclo_[3.3.2]decane              0.0
# ring:polycycle_spiro_[4.5]decane                  0.0
# ring:polycycle_tricyclo_adamantane                0.0
# count                                            33.0
#
#                                       indoles and derivatives  benzazepines  \
# atom:element_metal_group_I_II                             2.0           0.0
# atom:element_metal_metalloid                              0.0           0.0
# atom:element_metal_transistion_metal                      0.0           0.0
# bond:C#N_cyano_acylcyanide                                0.0           0.0
# bond:C#N_cyano_cyanamide                                  0.0           0.0
# ...                                                       ...           ...
# ring:polycycle_bicyclo_[3.3.1]nonane                      0.0           0.0
# ring:polycycle_bicyclo_[3.3.2]decane                      0.0           0.0
# ring:polycycle_spiro_[4.5]decane                          0.0           0.0
# ring:polycycle_tricyclo_adamantane                        0.0           0.0
# count                                                    59.0          22.0
#
#                                       triazines  ...  \
# atom:element_metal_group_I_II               4.0  ...
# atom:element_metal_metalloid                0.0  ...
# atom:element_metal_transistion_metal        0.0  ...
# bond:C#N_cyano_acylcyanide                  0.0  ...
# bond:C#N_cyano_cyanamide                    1.0  ...
# ...                                         ...  ...
# ring:polycycle_bicyclo_[3.3.1]nonane        0.0  ...
# ring:polycycle_bicyclo_[3.3.2]decane        0.0  ...
# ring:polycycle_spiro_[4.5]decane            0.0  ...
# ring:polycycle_tricyclo_adamantane          0.0  ...
# count                                      53.0  ...
#
#                                       cinnamic acids and derivatives  \
# atom:element_metal_group_I_II                                    0.0
# atom:element_metal_metalloid                                     0.0
# atom:element_metal_transistion_metal                             0.0
# bond:C#N_cyano_acylcyanide                                       0.0
# bond:C#N_cyano_cyanamide                                         0.0
# ...                                                              ...
# ring:polycycle_bicyclo_[3.3.1]nonane                             0.0
# ring:polycycle_bicyclo_[3.3.2]decane                             0.0
# ring:polycycle_spiro_[4.5]decane                                 0.0
# ring:polycycle_tricyclo_adamantane                               0.0
# count                                                           14.0
#
#                                       diazinanes  pyridopyrimidines  \
# atom:element_metal_group_I_II                0.0                1.0
# atom:element_metal_metalloid                 0.0                0.0
# atom:element_metal_transistion_metal         0.0                0.0
# bond:C#N_cyano_acylcyanide                   0.0                0.0
# bond:C#N_cyano_cyanamide                     0.0                0.0
# ...                                          ...                ...
# ring:polycycle_bicyclo_[3.3.1]nonane         0.0                0.0
# ring:polycycle_bicyclo_[3.3.2]decane         0.0                0.0
# ring:polycycle_spiro_[4.5]decane             0.0                0.0
# ring:polycycle_tricyclo_adamantane           0.0                0.0
# count                                       61.0               12.0
#
#                                       organic sulfuric acids and derivatives  \
# atom:element_metal_group_I_II                                            9.0
# atom:element_metal_metalloid                                             0.0
# atom:element_metal_transistion_metal                                     0.0
# bond:C#N_cyano_acylcyanide                                               0.0
# bond:C#N_cyano_cyanamide                                                 0.0
# ...                                                                      ...
# ring:polycycle_bicyclo_[3.3.1]nonane                                     0.0
# ring:polycycle_bicyclo_[3.3.2]decane                                     0.0
# ring:polycycle_spiro_[4.5]decane                                         0.0
# ring:polycycle_tricyclo_adamantane                                       0.0
# count                                                                   24.0
#
#                                       organic dithiophosphoric acids and derivatives  \
# atom:element_metal_group_I_II                                                    4.0
# atom:element_metal_metalloid                                                     0.0
# atom:element_metal_transistion_metal                                             0.0
# bond:C#N_cyano_acylcyanide                                                       0.0
# bond:C#N_cyano_cyanamide                                                         0.0
# ...                                                                              ...
# ring:polycycle_bicyclo_[3.3.1]nonane                                             0.0
# ring:polycycle_bicyclo_[3.3.2]decane                                             0.0
# ring:polycycle_spiro_[4.5]decane                                                 0.0
# ring:polycycle_tricyclo_adamantane                                               0.0
# count                                                                           44.0
#
#                                       isoindoles and derivatives  azoles  \
# atom:element_metal_group_I_II                                0.0     5.0
# atom:element_metal_metalloid                                 0.0     0.0
# atom:element_metal_transistion_metal                         0.0     0.0
# bond:C#N_cyano_acylcyanide                                   0.0     0.0
# bond:C#N_cyano_cyanamide                                     0.0     1.0
# ...                                                          ...     ...
# ring:polycycle_bicyclo_[3.3.1]nonane                         0.0     1.0
# ring:polycycle_bicyclo_[3.3.2]decane                         0.0     0.0
# ring:polycycle_spiro_[4.5]decane                             0.0     0.0
# ring:polycycle_tricyclo_adamantane                           0.0     1.0
# count                                                       27.0   139.0
#
#                                       piperidines  thioureas  benzopyrans
# atom:element_metal_group_I_II                 0.0        0.0          3.0
# atom:element_metal_metalloid                  0.0        0.0          0.0
# atom:element_metal_transistion_metal          0.0        0.0          0.0
# bond:C#N_cyano_acylcyanide                    0.0        0.0          0.0
# bond:C#N_cyano_cyanamide                      0.0        0.0          0.0
# ...                                           ...        ...          ...
# ring:polycycle_bicyclo_[3.3.1]nonane          0.0        0.0          0.0
# ring:polycycle_bicyclo_[3.3.2]decane          0.0        0.0          0.0
# ring:polycycle_spiro_[4.5]decane              0.0        0.0          0.0
# ring:polycycle_tricyclo_adamantane            0.0        0.0          0.0
# count                                        39.0       14.0         23.0
#
# [545 rows x 127 columns]

# %% [markdown]
# ### Comparing the distribution of features between the full set and a subset based on structure
#
# We choose the group "isoindoles and derivatives"
#
# With this, we can see how different the structures are (feature-wise) when compared to the full sets

# %%
import matplotlib.pyplot as plt

def plot_freq_comparison(df,grp,fp, filename):
    df2 = df.copy()
    df = df/df.iloc[-1]
    df = df.iloc[:-1]
    #df = df[df[grp]>0.05]
    X = df['full']
    Y = df[grp]
    fig, ax = plt.subplots()
    ax.plot(X,X,color='black')
    ax.scatter(X,Y,label=grp)
    #ax.set_title(f'Distribution of individual {fp} fragments',fontsize=22)
    ax.set_xlabel('fractional representation in full',fontsize=16)
    ax.set_ylabel('fractional representation in group',fontsize=16)
    ax.legend()
    fig.savefig(figures_dir+filename, dpi = 300)

    return df2[[grp,'full']].rename(columns={grp:'grp'})

# %% [markdown]
# The two figures above demonstrate the difference in fragment presence between the individual group and the full data set.
#
# Above the black line = Larger fraction of structures contained this fragment in the group compared to full set
#
# Below the line = Smaller fraction

# %%
df_freq_tox = plot_freq_comparison(df_tox,'isoindoles and derivatives','tox', 'Figure10b.png')

# %%
df_freq_aim = plot_freq_comparison(df_aim,'isoindoles and derivatives','aim', 'Figure10a.png')

# %%
classified = df_grps['N Struc'].sum()
N_unclassified = int(df.shape[0] - classified)

# Due to how the groups were chosen (we exclude those grps with less than 20),

print(f'There are {N_unclassified} unclassified chemicals')
# Out:
# There are 1462 unclassified chemicals

# %% [markdown]
# ## Further Investigation:Looking at the individual error differences for the specific group of interest
#
# - Are there any outliers?
# - or Consistent trend?

# %%
grp_name = 'isoindoles and derivatives'

grp_dataset = df3[df3['class']==grp_name]
if len(grp_dataset) == 0:
    grp_dataset = df3[df3['subclass']==grp_name]

X = grp_dataset['Diff_tox']
Y = grp_dataset['Diff_aim']
X2 = df3.iloc[1210]['Diff_tox']
Y2 = df3.iloc[1210]['Diff_aim']
plt.scatter(X,Y)
plt.scatter(X2,Y2,color='red')
plt.plot(X,X,color='black')
plt.xlabel('ToxPrint prediction absolute error')
plt.ylabel('AIM prediction absolute error')
plt.savefig(figures_dir+'Figure11.png', dpi = 300)

# %% [markdown]
# ## Toxicity vs Similarity plot
#
# Since our chemicals are predicted by nearest neighbors, we want to see why predictions are bad/good

# %%
# Getting a list of our groups
grps = df_grps.index.to_list()

df3['Diff_errs'] = df3['Diff_tox']-df3['Diff_aim']
df3[df3['class']=='isoindoles and derivatives'].sort_values(by=['Diff_errs']).head(1)
# Out:
#              dtxsid                       class      subclass  Y_pred_aim  \
# 3916  DTXSID9022524  isoindoles and derivatives  isoindolines   -1.091156
#
#       Diff_aim                                           aim_list    Y_true  \
# 3916   1.45009  [ CH2 [aliphatic carbon],  CH [aliphatic carbo...  0.358933
#
#       Y_pred_tox  Diff_tox                                           tox_list  \
# 3916   -0.446752  0.805685  [bond:C(=O)N_carboxamide_(NHR), bond:C(=O)N_ca...
#
#       Diff_errs
# 3916  -0.644405

# %% [markdown]
# ## Using Jaccard Similarity
# $$
#   J(A,B) = \frac{|A \cap B|}{|A \cup B|}
# $$
#
#
# We can calculate jaccard for a given structure by comparing the two lists of features
#
# (N shared features by both) / (total features between both structures)

# %%
# Get jaccard just gives us the 
def get_jaccard(lst_0,lst_1):
    a = [item for item in lst_0 if item in lst_1]   # Features shared byBoth 
    b = [item for item in lst_0 if item not in lst_1] # Features in Struct 1 only
    c = [item for item in lst_1 if item not in lst_0] # Features in Struct 2 only

    jaccard = len(a)/(len(a)+len(b)+len(c))
    
    return jaccard

def all_jaccards(N,df,fp_set):
    lst_0 = df[f'{fp_set}_list'].iloc[[N]][N]

    data = []
    for i,row in df[[f'{fp_set}_list']].iterrows():
        lst_1 = df[f'{fp_set}_list'].iloc[[i]][i]
        jac = get_jaccard(lst_0,lst_1)
        if df.iloc[[N]]['class'][N] in grps:
            grp = df.iloc[[i]]['class'][i]
        else:
            grp = df.iloc[[i]]['subclass'][i]
        data.append([jac,grp])
    dfj = pd.DataFrame(data)
    dfj.name = N
    
    return dfj, N


def make_plot(N,df,fp_set, filename):
    df2, N = all_jaccards(N,df,fp_set)
    df_n = pd.merge(df,df2,how='outer',left_index=True,right_index=True)
    df_n = df_n.rename(columns={0:f'row {N} Similarity',1:'group'})
    
    X = df_n[f'row {N} Similarity'][1:]
    Y = df_n['Y_true'][1:]

    grp = df_n.iloc[[N]]['group'][N] 
    df_n_sub = df_n[df_n['group']==grp]

    X3 =  df_n[f'row {N} Similarity'][N:N+1]
    Y3 = df_n['Y_true'][N:N+1]

    plt.figure(figsize=(6,4))
    plt.scatter(X,Y,label='all')
    plt.scatter(X3,Y3,label='individual true',color='red')
    plt.axhline(y=df_n[f'Y_pred_{fp_set}'][N:N+1].iloc[0],color='black',label='prediction')
    plt.xlabel('Jaccard similarity')
    plt.ylabel('LD50  logmolar')
    plt.legend()
    plt.savefig(figures_dir+filename, dpi = 300)
    return df_n

# %%
df_x = make_plot(1210,df3,'aim', 'Figure12a.png')
# Better prediction due to the nearest neighbors being close in toxicity

# %%
# Worse prediction due to the nearest neighbors being dissimilar in toxicity
df_x = make_plot(1210,df3,'tox', 'Figure12b.png')

# %% [markdown]
# ### Process for selecting N (for above plot)
#
# 1. Select group of interest
# 2. Filter df3 by selecting chemicals only within group of interest
# 3. Select chemical in group of interest by some metric (error), the index number of that chemical is N

# %%
grp_name = 'phenoxyacetic acid derivatives'

grp_dataset = df3[df3['class']==grp_name]
if len(grp_dataset) == 0:
    grp_dataset = df3[df3['subclass']==grp_name]

X = grp_dataset['Diff_tox']
Y = grp_dataset['Diff_aim']
X2 = df3.iloc[3359]['Diff_tox']
Y2 = df3.iloc[3359]['Diff_aim']
plt.scatter(X,Y)
plt.scatter(X2,Y2,color='red')
plt.plot(X,X,color='black')
plt.xlabel('ToxPrint prediction absolute error')
plt.ylabel('AIM prediction absolute error')
plt.savefig(figures_dir+'FigureS1.png', dpi = 300)

# %%
plt.style.use('seaborn')
X = df_grps['Error_tox']
Y = df_grps['Error_aim']
plt.figure(figsize=(6,4))
plt.plot(X,X,color='black')
plt.scatter(X,Y)
plt.ylim([0.1,1])
plt.xlim([0.1,1])
plt.ylabel('Error Aim')
plt.xlabel('Error Tox')
plt.title('Classes and Errors')
# Out:
# Text(0.5, 1.0, 'Classes and Errors')

# %%
#1
group = df_grps.sort_values(by=['Error_tox']).index[0] #Group which has lowest abs error

#2
grp_dataset = df3[df3['class']==group]
if len(grp_dataset) == 0:
    grp_dataset = df3[df3['subclass']==group]
#3
num = grp_dataset.sort_values(by=['Diff_tox']).index[0] # smallest error in group

# %%
df_x = make_plot(3359,df3,'tox', 'Figure13b.png')

# %%
df_x = make_plot(3359,df3,'aim', 'Figure13a.png')

# %%
#1
group = df_grps.sort_values(by=['Error_tox'],ascending=False).index[0] #Group which has LARGEST abs error

#2
grp_dataset = df3[df3['class']==group]
if len(grp_dataset) == 0:
    grp_dataset = df3[df3['subclass']==group]
#3
num = grp_dataset.sort_values(by=['Diff_tox'],ascending=False).index[0] # LARGEST error in group

# %%
df_x = make_plot(num,df3,'tox')

# %%
df_x = make_plot(num,df3,'aim')

# %%
df3[df3['dtxsid'] == 'DTXSID0021385']
# Out:
#              dtxsid                       class      subclass  Y_pred_aim  \
# 1210  DTXSID0021385  isoindoles and derivatives  isoindolines   -0.892162
#
#       Diff_aim                                           aim_list    Y_true  \
# 1210  0.056686  [C [aliphatic carbon No H, not tert],  N [alip... -0.948847
#
#       Y_pred_tox  Diff_tox                                           tox_list  \
# 1210   -0.273474  0.675374  [bond:C(=O)N_carboxamide_generic, bond:C=O_car...
#
#       Diff_errs
# 1210   0.618688

# %%
df3[df3['dtxsid'] == 'DTXSID2034700']
# Out:
#              dtxsid                                class  \
# 3359  DTXSID2034700  benzene and substituted derivatives
#
#                             subclass  Y_pred_aim  Diff_aim  \
# 3359  phenoxyacetic acid derivatives   -0.748312  0.192747
#
#                                                aim_list    Y_true  Y_pred_tox  \
# 3359  [ CH3 [aliphatic carbon],  CH2 [aliphatic carb... -0.555565   -0.577682
#
#       Diff_tox                                           tox_list  Diff_errs
# 3359  0.022117  [atom:element_metal_group_I_II, bond:C(=O)O_ca...   -0.17063
