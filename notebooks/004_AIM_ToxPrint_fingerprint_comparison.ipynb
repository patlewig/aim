# %% [markdown]
# <a href="https://colab.research.google.com/github/patlewig/aim/blob/master/notebooks/fingerprint_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Compare AIM Fingerprints to ToxPrints
#
#
# #### QAPP ID: I-CCED-0032994-QP-1-0
# #### Author: Matthew Adams
# #### Principal Investigator: Grace Patlewicz
# #### Last Modified Jun 29 2022

# %%
from datetime import date
today = date.today()
day = today.strftime("%m_%d_%y")
import pandas as pd
import collections
import numpy as np
import matplotlib.pyplot as plt
import pickle
import os
import openpyxl
# %matplotlib inline

# %%
TOP = os.getcwd().replace('notebooks', '')
raw_dir = TOP + 'data/raw/'
interim_dir = TOP + 'data/interim/'
processed_dir = TOP + 'data/processed/'
external_dir = TOP + 'data/external/'
figures_dir = TOP + 'reports/figures/'
refs_dir = TOP + 'references/'

# %% [markdown]
# ## Build Confusion Matrix
#
# Inputs:
# - 2 fingerprint files from CORINA (.txt format) read as df objects
#     - Input needed for CORINA:
#         - TOXPRINT_SUPERSET.smi file
#         - AIM.xml file (set 1)
#         - Toxprints.xml file (set 2)
#
# - Remove any errors and non-fingerprint columns before building matrix
#
#
# Outputs:
#
# - Pickle file of confusion matrix dataframe
#
#
# <div class="alert alert-info">
#
# **Note:** It will take about an hour to build a new matrix
#
# </div>

# %%
from collections import Counter

df_toxprints = pd.read_csv(raw_dir+'toxprint_output.txt', sep=';')
df_toxprints = df_toxprints[df_toxprints['M_CORINA_SYMPHONY_ERRORS_[STRING]'] == 'No errors']
df_1 = df_toxprints.iloc[:,1:-2]

# Due to the way that the AIM CSRML file was created, 
#there are duplicate subgraphs acting as a single fingerprint 
# that must be combined into one column before running 

df_aim = pd.read_csv(raw_dir+'aim_output.txt', sep=';')
df_aim = df_aim[df_aim['M_CORINA_SYMPHONY_ERRORS_[STRING]'] == 'No errors']
df_0 = df_aim.iloc[:,1:-2]

def clean_aim_df(df_0):
    """
    combines duplicate columns in aim fragment fp dataframe
        Args: 
            df_0, dataframe object
    
        Returns: 
            df_0, dataframe, object
        """
    col_names = []
    for i in df_0.columns:
        col_names.append(i.split('.')[0])    
    mylist = Counter(col_names)
    duplicate_list= {key: value for key, value in mylist.items() if value > 1}

    len_dict = len(duplicate_list)
    sum_dict = sum(duplicate_list.values())
    print(f'{sum_dict-len_dict} columns to be removed')

    cols = []
    for i in df_0.columns:
        if i.split('.')[0] in duplicate_list.keys():
            cols.append(i)

    df_dupes = df_0[cols].copy()
    for i,col in enumerate(df_dupes):
        col_1 = df_dupes.iloc[:,i].name.split('.')[0]
        for j, col2 in enumerate(df_dupes):
            col_2 = df_dupes.iloc[:,j].name.split('.')[0]
            if col_1 == col_2:
                df_dupes[col] = df_dupes[[col,col2]].max(axis=1)



    n_before = df_0.shape[1]
    for col in df_dupes:
        if len(col.split('.')) >= 2:
            if col.split('.')[1].isdigit() == True:
                df_0 = df_0.drop(columns=[col])
            elif col.split('.')[1].isdigit() == False:
                if len(col.split('.')) > 2:
                    df_0 = df_0.drop(columns=[col])
        else:
            df_0[col] = df_dupes[col]


    df_0
    n_after = df_0.shape[1]

    print(f'{n_before-n_after} columns removed')
    return df_0
    
df_0 = clean_aim_df(df_0)
# Out:
# 85 columns to be removed
# 85 columns removed

# %%
def build_comparison_matrix(df_0,df_1,filename="pickled_df"):
    """
    Builds a comparison matrix
    
    Args:
        df_0 (object):
        df_1 (object):
        filename (str):
    Returns:
        df_2 (object):
    """
    df_2 = pd.DataFrame(columns = [df_0.columns], index=[df_1.columns])
    for i, col in enumerate(df_0):
        a = []
        for j, col in enumerate(df_1):
            df_cross = pd.crosstab(df_0.iloc[:,i],df_1.iloc[:,j], dropna=False)[::-1]
            #print(df_cross)
            if df_cross.shape[1] == 1:
                df_cross['1'] = 0

            df_cross = df_cross[df_cross.columns[::-1]]
            df_cross = df_cross.transpose()

            if df_cross.shape[1] == 1:
                df_cross.insert(0,'1',0)
            
            a.append(df_cross.to_numpy())

        df_2.iloc[:,i] = a

    df_2.pickle.dump(processed_dir+f"{filename}_{day}.pkl")
    return df_2

# %%
df_2 = pickle.load( open( processed_dir+"aim_tox_clean_compare.pkl", "rb" ) )

# %%
# Read a previously built confusion matrix
#df_2 = pd.read_pickle(processed_dir+'aim_tox_clean_compare.pkl')
df_2.shape
# Out:
# (729, 783)

# %%
df_2.head()
# Out:
#                                       CH3 [aliphatic carbon]  \
# atom:element_main_group            [[0, 274], [16570, 9065]]
# atom:element_metal_group_I_II  [[1225, 1718], [15345, 7621]]
# atom:element_metal_group_III      [[24, 210], [16546, 9129]]
# atom:element_metal_metalloid     [[774, 493], [15796, 8846]]
# atom:element_metal_poor_metal    [[218, 309], [16352, 9030]]
#
#                                       CH2 [aliphatic carbon]  \
# atom:element_main_group            [[0, 274], [16188, 9447]]
# atom:element_metal_group_I_II  [[1078, 1865], [15110, 7856]]
# atom:element_metal_group_III      [[10, 224], [16178, 9497]]
# atom:element_metal_metalloid     [[597, 670], [15591, 9051]]
# atom:element_metal_poor_metal    [[188, 339], [16000, 9382]]
#
#                                       CH [aliphatic carbon]  \
# atom:element_main_group           [[0, 274], [7787, 17848]]
# atom:element_metal_group_I_II  [[500, 2443], [7287, 15679]]
# atom:element_metal_group_III      [[6, 228], [7781, 17894]]
# atom:element_metal_metalloid   [[127, 1140], [7660, 16982]]
# atom:element_metal_poor_metal    [[57, 470], [7730, 17652]]
#
#                               C [aliphatic carbon No H, not tert]  \
# atom:element_main_group                 [[0, 274], [2444, 23191]]
# atom:element_metal_group_I_II        [[268, 2675], [2176, 20790]]
# atom:element_metal_group_III            [[4, 230], [2440, 23235]]
# atom:element_metal_metalloid          [[38, 1229], [2406, 22236]]
# atom:element_metal_poor_metal           [[6, 521], [2438, 22944]]
#
#                                     =CH2 [olefinic carbon]  \
# atom:element_main_group          [[0, 274], [1336, 24299]]
# atom:element_metal_group_I_II  [[63, 2880], [1273, 21693]]
# atom:element_metal_group_III     [[0, 234], [1336, 24339]]
# atom:element_metal_metalloid   [[92, 1175], [1244, 23398]]
# atom:element_metal_poor_metal    [[5, 522], [1331, 24051]]
#
#                                  =CH or =C [olefinc carbon]  \
# atom:element_main_group           [[0, 274], [5065, 20570]]
# atom:element_metal_group_I_II  [[342, 2601], [4723, 18243]]
# atom:element_metal_group_III      [[3, 231], [5062, 20613]]
# atom:element_metal_metalloid   [[121, 1146], [4944, 19698]]
# atom:element_metal_poor_metal    [[39, 488], [5026, 20356]]
#
#                                   #C [acetylenic carbon]  \
# atom:element_main_group         [[1, 273], [217, 25418]]
# atom:element_metal_group_I_II  [[6, 2937], [212, 22754]]
# atom:element_metal_group_III    [[0, 234], [218, 25457]]
# atom:element_metal_metalloid   [[6, 1261], [212, 24430]]
# atom:element_metal_poor_metal   [[0, 527], [218, 25164]]
#
#                                OH [hydroxy, aliphatic attach]  \
# atom:element_main_group             [[0, 274], [3530, 22105]]
# atom:element_metal_group_I_II    [[217, 2726], [3313, 19653]]
# atom:element_metal_group_III        [[2, 232], [3528, 22147]]
# atom:element_metal_metalloid      [[44, 1223], [3486, 21156]]
# atom:element_metal_poor_metal      [[14, 513], [3516, 21866]]
#
#                                O [oxygen, aliphatic attach]  \
# atom:element_main_group           [[0, 274], [2904, 22731]]
# atom:element_metal_group_I_II  [[186, 2757], [2718, 20248]]
# atom:element_metal_group_III      [[0, 234], [2904, 22771]]
# atom:element_metal_metalloid    [[300, 967], [2604, 22038]]
# atom:element_metal_poor_metal    [[15, 512], [2889, 22493]]
#
#                                     NH2 [aliphatic attach]  ...  \
# atom:element_main_group          [[0, 274], [1741, 23894]]  ...
# atom:element_metal_group_I_II  [[92, 2851], [1649, 21317]]  ...
# atom:element_metal_group_III     [[0, 234], [1741, 23934]]  ...
# atom:element_metal_metalloid   [[35, 1232], [1706, 22936]]  ...
# atom:element_metal_poor_metal    [[3, 524], [1738, 23644]]  ...
#
#                               N CH=N OH [oxime type] correction  \
# atom:element_main_group                 [[0, 274], [14, 25621]]
# atom:element_metal_group_I_II          [[1, 2942], [13, 22953]]
# atom:element_metal_group_III            [[0, 234], [14, 25661]]
# atom:element_metal_metalloid           [[1, 1266], [13, 24629]]
# atom:element_metal_poor_metal           [[0, 527], [14, 25368]]
#
#                               Ring rx: OH ortho to C=N N carbon  \
# atom:element_main_group                  [[0, 274], [3, 25632]]
# atom:element_metal_group_I_II           [[0, 2943], [3, 22963]]
# atom:element_metal_group_III             [[0, 234], [3, 25672]]
# atom:element_metal_metalloid            [[0, 1267], [3, 24639]]
# atom:element_metal_poor_metal            [[0, 527], [3, 25379]]
#
#                               =C (C#N) C#N [dicyano] correction  \
# atom:element_main_group                 [[0, 274], [16, 25619]]
# atom:element_metal_group_I_II          [[0, 2943], [16, 22950]]
# atom:element_metal_group_III            [[0, 234], [16, 25659]]
# atom:element_metal_metalloid           [[0, 1267], [16, 24626]]
# atom:element_metal_poor_metal           [[0, 527], [16, 25366]]
#
#                               Aromatic nitrogen C C(=S) N struct corr.  \
# atom:element_main_group                         [[0, 274], [0, 25635]]
# atom:element_metal_group_I_II                  [[0, 2943], [0, 22966]]
# atom:element_metal_group_III                    [[0, 234], [0, 25675]]
# atom:element_metal_metalloid                   [[0, 1267], [0, 24642]]
# atom:element_metal_poor_metal                   [[0, 527], [0, 25382]]
#
#                               Cyclic ketoxime(>C=N OH) [1 olefin attach]  \
# atom:element_main_group                           [[0, 274], [2, 25633]]
# atom:element_metal_group_I_II                    [[0, 2943], [2, 22964]]
# atom:element_metal_group_III                      [[0, 234], [2, 25673]]
# atom:element_metal_metalloid                     [[0, 1267], [2, 24640]]
# atom:element_metal_poor_metal                     [[0, 527], [2, 25380]]
#
#                               C=N O sulfur(aliphatic) [iminoxy] correc  \
# atom:element_main_group                         [[0, 274], [8, 25627]]
# atom:element_metal_group_I_II                  [[1, 2942], [7, 22959]]
# atom:element_metal_group_III                    [[0, 234], [8, 25667]]
# atom:element_metal_metalloid                   [[0, 1267], [8, 24634]]
# atom:element_metal_poor_metal                   [[0, 527], [8, 25374]]
#
#                                S N( C(=O) C) C(=O) C struct correction  \
# atom:element_main_group                         [[0, 274], [3, 25632]]
# atom:element_metal_group_I_II                  [[0, 2943], [3, 22963]]
# atom:element_metal_group_III                    [[0, 234], [3, 25672]]
# atom:element_metal_metalloid                   [[0, 1267], [3, 24639]]
# atom:element_metal_poor_metal                   [[0, 527], [3, 25379]]
#
#                                Sulfur(+4) charged halide type  \
# atom:element_main_group                [[0, 274], [0, 25635]]
# atom:element_metal_group_I_II         [[0, 2943], [0, 22966]]
# atom:element_metal_group_III           [[0, 234], [0, 25675]]
# atom:element_metal_metalloid          [[0, 1267], [0, 24642]]
# atom:element_metal_poor_metal          [[0, 527], [0, 25382]]
#
#                               Ring rx: S=P(O)(O)O / 5 mem (2 nitrogen)  \
# atom:element_main_group                         [[0, 274], [2, 25633]]
# atom:element_metal_group_I_II                  [[0, 2943], [2, 22964]]
# atom:element_metal_group_III                    [[0, 234], [2, 25673]]
# atom:element_metal_metalloid                   [[0, 1267], [2, 24640]]
# atom:element_metal_poor_metal                   [[0, 527], [2, 25380]]
#
#                               O=P( O)( O) C OH correction
# atom:element_main_group            [[0, 274], [2, 25633]]
# atom:element_metal_group_I_II     [[0, 2943], [2, 22964]]
# atom:element_metal_group_III       [[0, 234], [2, 25673]]
# atom:element_metal_metalloid      [[0, 1267], [2, 24640]]
# atom:element_metal_poor_metal      [[0, 527], [2, 25380]]
#
# [5 rows x 783 columns]

# %% [markdown]
# ## Plotting the distributions
# We want to look at the overall distribution of the Fragments across the data space

# %%
df_1_sums = df_1.sum(numeric_only=True,axis=0)
df_0_sums = df_0.sum(numeric_only=True,axis=0)

def plot_loghist(x, bins,color, filename):
    hist, bins = np.histogram(x, bins=bins)
    logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
    plt.hist(x, bins=logbins,color=color,edgecolor='black',linewidth='1')
    plt.ylabel('Fragment Frequency')
    plt.xlabel('Number of Compounds')
    plt.xscale('log')
    plt.savefig(figures_dir+filename, dpi = 300)
x = np.array(df_0_sums)
x = x[x!=0]
print(x.mean())

#plt.title('AIM Fragments')
plot_loghist(x, 20,'skyblue', 'Figure4.png')
# Out:
# 285.6373801916933

# %%
x = np.array(df_1_sums)
x = x[x!=0]
print(x.mean())

#plt.title('Toxprints')
plot_loghist(x, 20,'tomato', 'Figure4b.png')
# Out:
# 454.42587209302326

# %%
# Manual test to check that the confusion matrix was built properly...

i = 1
j = 4

df_temp = pd.merge(df_0.iloc[:,i],df_1.iloc[:,j],left_index=True,right_index=True)


TP = df_temp[(df_temp != 0).all(1)].shape[0]  #n rows which both features show up
TN = (df_temp.shape[0] - df_temp[(df_temp != 0).any(1)].shape[0]) # n rows which neither show
FP = sum(df_temp[df_temp.iloc[:,0] == 0].iloc[:,1]) #n rows where only TOX feature
FN = sum(df_temp[df_temp.iloc[:,1] == 0].iloc[:,0]) #n rows where only AIM feature

print(df_2.iloc[:,i].name[0])
print(df_2.iloc[j,:].name[0])
print(np.reshape(df_2.iloc[j,i],(4,)).tolist())

print(df_0.iloc[:,i].name)
print(df_1.iloc[:,j].name)
print([TP,FP,FN,TN])


print(sum(df_0.iloc[:,i]),(TP+FN),df_0.iloc[:,i].name)
print(sum(df_1.iloc[:,j]),(TP+FP),df_1.iloc[:,j].name)

# [Tox+AIM,TOX_only,AIM_only,None]
# Out:
#  CH2 [aliphatic carbon]
# atom:element_metal_poor_metal
# [188, 339, 16000, 9382]
#  CH2 [aliphatic carbon]
# atom:element_metal_poor_metal
# [188, 339, 16000, 9382]
# 16188 16188  CH2 [aliphatic carbon]
# 527 527 atom:element_metal_poor_metal

# %% [markdown]
# ## Direct Comparison of Individual Fragments in each Set
#
# We want to see if there is a existing toxprint that already captures the same features as an aim fragment
#
# To do that we can use Jaccard similarity index to see how their preseence overlaps in the chemical space

# %%
import pandas as pd
import collections
import numpy as np
import matplotlib.pyplot as plt

# Filter dataframe - what if the fragments don't show up at all in the structure (No FN or TP)
# AIM:Toxprint to see there is a existing toxprint that already captures the same features as an aim fragment
#then do Toxprint:AIM to see if there are aim fragments that match respective toxprints

def fragment_compare(df,coln,transpose=False):
    """Description goes here.
    
    Args: 
        df (object):
        coln (int):
        transpose (bool):
        
    Returns: 
        df2 (object):
    
    """
    if transpose==True:
        df = df.T
    df1 = df.iloc[:,coln]
    df2= df1.apply(lambda x: np.reshape(x,(4,)).tolist())
    df2 = pd.DataFrame(df2).reset_index()
    df2.columns = ['Fragment Name', 'Count']
    df2.index.name = df1.name
    df2[['TP','FP','FN','TN']] = pd.DataFrame(df2.Count.tolist(),index=df2.index)
    df2['(TP+FP+FN)'] = df2[['TP','FP','FN']].sum(axis=1)
    df2['FP/(TP+FP+FN) (Tox Only)'] = df2['FP'].div(df2['(TP+FP+FN)'])
    df2['TP/(TP+FP+FN) (Jaccard)'] = df2['TP'].div(df2['(TP+FP+FN)'])
    df2['FN/(TP+FP+FN) (AIM Only)'] = df2['FN'].div(df2['(TP+FP+FN)'])

    return df2

def most_alike(df,col_name,transpose=False):
    """Description goes here.
    
    Args: 
        df (object):
        col_name (str):
        transpose (bool):
    Returns: 
        comp_info (dict):
    
    """
    df = df.sort_values(by=[col_name], ascending=False, key= lambda col: col.map(lambda x: x))
    AIM_name = str(df.index.name).strip("('',)")
    toxprint_name = df.iloc[0,0]
    attribute = df[col_name].loc[df[col_name].idxmax()]
    comp_info = {AIM_name + "; " + toxprint_name:[attribute]}
    #print(comp_info)
    return comp_info

def plot_comparison(df,col_name,filename,transpose=False):
    """Description goes here.
    
    Args: 
        df (object):
        col_name (str):
        filename (str):
        transpose (bool):
        
    Returns: 
        
    """
    max_dict = {}
    skipped = 0
    for i in range(df.shape[transpose==False]):
        df2 = fragment_compare(df,i,transpose)
        if transpose==False:
            df2 = df2[(df2['FN'] > 0) | (df2['TP'] > 0)]
        else:
            df2 = df2[(df2['FP'] > 0) | (df2['TP'] > 0)]
        if df2.shape[0] == 0:
            skipped+=1
            continue
        max_dict.update(most_alike(df2,col_name,transpose))

    print("Skipped due to no presence within dataset:",skipped)
    pd.set_option('display.max_rows', 10) #Change to 'None' to show all rows
    pd.set_option('display.max_colwidth', None)

    max_df = pd.DataFrame.from_dict(max_dict, orient='index', columns=[col_name])
    max_df.reset_index(inplace=True)
    max_df = max_df.rename(columns={"index":"AIM:Toxprint Pair"})
    
    
    X = max_df.iloc[:,1]
    print(X.mean())
    print(X.shape)
    #print(max_df.head())
    if transpose==False:
        plt.title('AIM:Tox')
        color = 'lightblue'
    else:
        plt.title('TOX:AIM')
        color='tomato'
        
    plt.rcParams.update({'font.size':18})
    plt.yticks(np.arange(0,350,50))
    plt.ylim(0,350)
    plt.ylabel('N pairs')
    plt.xlabel('Max(Jaccard(AIM,Tox))')
    n,bins,patches = plt.hist(X,bins=10,color=color,edgecolor='black',linewidth=1)

# %%
#Picking a random fragment
df = fragment_compare(df_2,19)
df = df.sort_values(by=['TP/(TP+FP+FN) (Jaccard)'], ascending=False, key= lambda col: col.map(lambda x: x))
df[['Fragment Name', 'TP/(TP+FP+FN) (Jaccard)']]


most_alike(df,'TP/(TP+FP+FN) (Jaccard)')
df
# Out:
#                                                          Fragment Name  \
# (Aromatic Carbon,)
# 585                                              ring:aromatic_benzene
# 476                         chain:aromaticAlkane_Ph-C1_acyclic_generic
# 70                                           bond:C=O_carbonyl_generic
# 475                 chain:aromaticAlkane_Ph-C1_acyclic_connect_noDblBd
# 301                                                 bond:X[any]_halide
# ...                                                                ...
# 401                                   bond:metal_transition_Mo_sulfide
# 404                                   bond:metal_transition_Pt_generic
# 405                                    bond:metal_transition_Pt_halide
# 406                                  bond:metal_transition_Pt_nitrogen
# 728                                 ring:polycycle_tricyclo_benzvalene
#
#                                         Count     TP    FP     FN     TN  \
# (Aromatic Carbon,)
# 585                   [11586, 0, 1211, 13112]  11586     0   1211  13112
# 476                    [6571, 0, 6226, 13112]   6571     0   6226  13112
# 70                   [6540, 5956, 6257, 7156]   6540  5956   6257   7156
# 475                    [4334, 0, 8463, 13112]   4334     0   8463  13112
# 301                 [4146, 2271, 8651, 10841]   4146  2271   8651  10841
# ...                                       ...    ...   ...    ...    ...
# 401                      [0, 2, 12797, 13110]      0     2  12797  13110
# 404                     [0, 22, 12797, 13090]      0    22  12797  13090
# 405                     [0, 12, 12797, 13100]      0    12  12797  13100
# 406                      [0, 5, 12797, 13107]      0     5  12797  13107
# 728                      [0, 0, 12797, 13112]      0     0  12797  13112
#
#                     (TP+FP+FN)  FP/(TP+FP+FN) (Tox Only)  \
# (Aromatic Carbon,)
# 585                      12797                  0.000000
# 476                      12797                  0.000000
# 70                       18753                  0.317603
# 475                      12797                  0.000000
# 301                      15068                  0.150717
# ...                        ...                       ...
# 401                      12799                  0.000156
# 404                      12819                  0.001716
# 405                      12809                  0.000937
# 406                      12802                  0.000391
# 728                      12797                  0.000000
#
#                     TP/(TP+FP+FN) (Jaccard)  FN/(TP+FP+FN) (AIM Only)
# (Aromatic Carbon,)
# 585                                0.905368                  0.094632
# 476                                0.513480                  0.486520
# 70                                 0.348744                  0.333653
# 475                                0.338673                  0.661327
# 301                                0.275153                  0.574131
# ...                                     ...                       ...
# 401                                0.000000                  0.999844
# 404                                0.000000                  0.998284
# 405                                0.000000                  0.999063
# 406                                0.000000                  0.999609
# 728                                0.000000                  1.000000
#
# [729 rows x 10 columns]

# %%
#df

# %% [markdown]
# ## Plotting the Maximum Jaccard Similarity
#
# We are only interested in what the most similar fragment pair is, so we take the maximum after comparing the AIM fragment to each indivdual toxprint fragment and vice versa

# %%
#df_2 = pd.read_pickle(processed_dir+'aim_tox_clean_compare.pkl')

plot_comparison(df_2,'TP/(TP+FP+FN) (Jaccard)','1')
# Out:
# Skipped due to no presence within dataset: 157
# 0.23871148458164315
# (626,)

# %%
plot_comparison(df_2,'TP/(TP+FP+FN) (Jaccard)','2',True)
# Out:
# Skipped due to no presence within dataset: 41
# 0.28560262264874897
# (688, 2)

# %%
626-157
# Out:
# 469
